# %% [markdown]
# In this file, we load the actor characteristics "age", "sex", "race", and "ethnicity" into the data files for the mid features.

# %%
from pyAudioAnalysis import ShortTermFeatures as aF
from pyAudioAnalysis import audioBasicIO as aIO 
from pyAudioAnalysis import MidTermFeatures as mF
import numpy as np 
import plotly.graph_objs as go 
import plotly
import IPython

import pandas as pd

import os, shutil
import time

import matplotlib.pyplot as plt

import random
# Out:
# /home/mnoorani/anaconda3/lib/python3.9/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
# Load the file that contains actor ids and characteristics


actor_data = pd.read_csv('../VideoDemographics.csv')

# %%
# Load the mid term features data for the training and test sets


mid_data_train = pd.read_csv('midFeaturesTrainFinal.csv')
#mid_data_test  = pd.read_csv('midFeaturesTestSet.csv')

# %%
# Use actor_data to make dicts mapping actor id to characteristics


age_dict = {}
sex_dict = {}
race_dict = {}
ethnicity_dict = {}



for i in actor_data.index:
    actor_id = actor_data.at[i, 'ActorID']
    actor_age = actor_data.at[i, 'Age']
    actor_sex = actor_data.at[i, 'Sex']
    actor_race = actor_data.at[i, 'Race']
    actor_ethnicity = actor_data.at[i, 'Ethnicity']
    age_dict[actor_id] = actor_age
    sex_dict[actor_id] = actor_sex
    race_dict[actor_id] = actor_race
    ethnicity_dict[actor_id] = actor_ethnicity

# %%
# Get lists of characteristics in the order actors appear in mid_data_train:


age_list_train = []
sex_list_train = []
race_list_train = []
ethnicity_list_train = []


for j in mid_data_train.index:
    age = age_dict[mid_data_train.at[j, 'actorID']]
    age_list_train.append(age)
    
    sex = sex_dict[mid_data_train.at[j, 'actorID']]
    sex_list_train.append(sex)
    
    race = race_dict[mid_data_train.at[j, 'actorID']]
    race_list_train.append(race)
    
    ethnicity = ethnicity_dict[mid_data_train.at[j, 'actorID']]
    ethnicity_list_train.append(ethnicity)
    
# Get lists of characteristics in the order actors appear in mid_data_test:

#age_list_test = []
#sex_list_test = []
#race_list_test = []
#ethnicity_list_test = []


#for j in mid_data_test.index:
#    age = age_dict[mid_data_test.at[j, 'ActorID']]
#    age_list_test.append(age)
#    
#    sex = sex_dict[mid_data_test.at[j, 'ActorID']]
#    sex_list_test.append(sex)
#    
#    race = race_dict[mid_data_test.at[j, 'ActorID']]
#    race_list_test.append(race)
#    
#    ethnicity = ethnicity_dict[mid_data_test.at[j, 'ActorID']]
#    ethnicity_list_test.append(ethnicity)

# %%
mid_data_train
# Out:
#                FileID  actorID Emotion SentenceID  zcr_mean  energy_mean  \
# 0     1001_DFA_ANG_XX     1001     ANG        DFA  0.159956     0.012981
# 1     1001_DFA_DIS_XX     1001     DIS        DFA  0.175069     0.006502
# 2     1001_DFA_FEA_XX     1001     FEA        DFA  0.199849     0.016796
# 3     1001_DFA_HAP_XX     1001     HAP        DFA  0.148663     0.007960
# 4     1001_DFA_NEU_XX     1001     NEU        DFA  0.174283     0.010704
# ...               ...      ...     ...        ...       ...          ...
# 4871  1091_WSI_DIS_XX     1091     DIS        WSI  0.115959     0.008173
# 4872  1091_WSI_FEA_XX     1091     FEA        WSI  0.222025     0.007925
# 4873  1091_WSI_HAP_XX     1091     HAP        WSI  0.139819     0.017985
# 4874  1091_WSI_NEU_XX     1091     NEU        WSI  0.114266     0.004263
# 4875  1091_WSI_SAD_XX     1091     SAD        WSI  0.097614     0.009380
#
#       energy_entropy_mean  spectral_centroid_mean  spectral_spread_mean  \
# 0                2.988679                0.250490              0.224054
# 1                2.930843                0.258174              0.209151
# 2                2.999322                0.272570              0.202443
# 3                2.880264                0.235750              0.211387
# 4                2.833565                0.256034              0.201942
# ...                   ...                     ...                   ...
# 4871             2.828783                0.200164              0.215948
# 4872             2.950341                0.338406              0.260304
# 4873             2.802341                0.221524              0.214651
# 4874             2.846756                0.205376              0.220937
# 4875             2.994652                0.189096              0.210459
#
#       spectral_entropy_mean  ...  delta chroma_4_std  delta chroma_5_std  \
# 0                  1.342449  ...            0.024107            0.014803
# 1                  1.423432  ...            0.022395            0.015510
# 2                  1.399237  ...            0.007043            0.003129
# 3                  1.292553  ...            0.021737            0.005675
# 4                  1.413561  ...            0.031970            0.012929
# ...                     ...  ...                 ...                 ...
# 4871               0.725800  ...            0.026035            0.012841
# 4872               1.094057  ...            0.017277            0.025758
# 4873               0.752937  ...            0.015223            0.017986
# 4874               0.811273  ...            0.003359            0.017843
# 4875               0.659367  ...            0.003471            0.005169
#
#       delta chroma_6_std  delta chroma_7_std  delta chroma_8_std  \
# 0               0.017961            0.013412            0.008655
# 1               0.008768            0.014533            0.009661
# 2               0.006915            0.007791            0.013899
# 3               0.009277            0.026797            0.010147
# 4               0.017969            0.037496            0.013379
# ...                  ...                 ...                 ...
# 4871            0.008842            0.007892            0.005362
# 4872            0.029299            0.006912            0.001970
# 4873            0.012653            0.018009            0.012961
# 4874            0.018368            0.020915            0.010360
# 4875            0.003767            0.018057            0.013519
#
#       delta chroma_9_std  delta chroma_10_std  delta chroma_11_std  \
# 0               0.010352             0.009738             0.010600
# 1               0.002533             0.004223             0.007513
# 2               0.005247             0.003474             0.014306
# 3               0.010658             0.017229             0.013203
# 4               0.008354             0.005615             0.008907
# ...                  ...                  ...                  ...
# 4871            0.017915             0.016780             0.020343
# 4872            0.006664             0.012525             0.030749
# 4873            0.006186             0.015287             0.032246
# 4874            0.021104             0.021054             0.024364
# 4875            0.025609             0.037053             0.018066
#
#       delta chroma_12_std  delta chroma_std_std
# 0                0.004328              0.009167
# 1                0.003662              0.007296
# 2                0.005781              0.008250
# 3                0.010011              0.007488
# 4                0.007483              0.013592
# ...                   ...                   ...
# 4871             0.015986              0.008793
# 4872             0.019316              0.012804
# 4873             0.015019              0.010603
# 4874             0.011053              0.008904
# 4875             0.008651              0.008636
#
# [4876 rows x 140 columns]

# %%
# Add the characteristics columns to mid_data_train:


mid_data_train.insert(4, 'Age', age_list_train)
mid_data_train.insert(5, 'Sex', sex_list_train)
mid_data_train.insert(6, 'Race', race_list_train)
mid_data_train.insert(7, 'Ethnicity', ethnicity_list_train)

# %%
mid_data_train.head()
# Out:
#             FileID  actorID Emotion SentenceID  Age   Sex       Race  \
# 0  1001_DFA_ANG_XX     1001     ANG        DFA   51  Male  Caucasian
# 1  1001_DFA_DIS_XX     1001     DIS        DFA   51  Male  Caucasian
# 2  1001_DFA_FEA_XX     1001     FEA        DFA   51  Male  Caucasian
# 3  1001_DFA_HAP_XX     1001     HAP        DFA   51  Male  Caucasian
# 4  1001_DFA_NEU_XX     1001     NEU        DFA   51  Male  Caucasian
#
#       Ethnicity  zcr_mean  energy_mean  ...  delta chroma_4_std  \
# 0  Not Hispanic  0.159956     0.012981  ...            0.024107
# 1  Not Hispanic  0.175069     0.006502  ...            0.022395
# 2  Not Hispanic  0.199849     0.016796  ...            0.007043
# 3  Not Hispanic  0.148663     0.007960  ...            0.021737
# 4  Not Hispanic  0.174283     0.010704  ...            0.031970
#
#    delta chroma_5_std  delta chroma_6_std  delta chroma_7_std  \
# 0            0.014803            0.017961            0.013412
# 1            0.015510            0.008768            0.014533
# 2            0.003129            0.006915            0.007791
# 3            0.005675            0.009277            0.026797
# 4            0.012929            0.017969            0.037496
#
#    delta chroma_8_std  delta chroma_9_std  delta chroma_10_std  \
# 0            0.008655            0.010352             0.009738
# 1            0.009661            0.002533             0.004223
# 2            0.013899            0.005247             0.003474
# 3            0.010147            0.010658             0.017229
# 4            0.013379            0.008354             0.005615
#
#    delta chroma_11_std  delta chroma_12_std  delta chroma_std_std
# 0             0.010600             0.004328              0.009167
# 1             0.007513             0.003662              0.007296
# 2             0.014306             0.005781              0.008250
# 3             0.013203             0.010011              0.007488
# 4             0.008907             0.007483              0.013592
#
# [5 rows x 144 columns]

# %%
# Add the characteristics columns to mid_data_test:

#mid_data_test.insert(4, 'Age', age_list_test)
#mid_data_test.insert(5, 'Sex', sex_list_test)
#mid_data_test.insert(6, 'Race', race_list_test)
#mid_data_test.insert(7, 'Ethnicity', ethnicity_list_test)

# %%
#mid_data_test.head()

# %%
# Save the files to csv

mid_data_train.to_csv('midFeaturesTrainFinalWithChars.csv', index=False)
#mid_data_test.to_csv('midFeaturesTestSetWithChars.csv', index=False)
