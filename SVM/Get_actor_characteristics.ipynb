# %% [markdown]
# In this file, we load the actor characteristics "age", "sex", "race", and "ethnicity" into the data files for the mid features.

# %%
from pyAudioAnalysis import ShortTermFeatures as aF
from pyAudioAnalysis import audioBasicIO as aIO 
from pyAudioAnalysis import MidTermFeatures as mF
import numpy as np 
import plotly.graph_objs as go 
import plotly
import IPython

import pandas as pd

import os, shutil
import time

import matplotlib.pyplot as plt

import random
# Out:
# /home/mnoorani/anaconda3/lib/python3.9/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
# Load the file that contains actor ids and characteristics


actor_data = pd.read_csv('../VideoDemographics.csv')

# %%
# Load the mid term features data for the training and test sets


mid_data_train = pd.read_csv('midFeaturesTestFinal.csv')
#mid_data_test  = pd.read_csv('midFeaturesTestSet.csv')

# %%
# Use actor_data to make dicts mapping actor id to characteristics


age_dict = {}
sex_dict = {}
race_dict = {}
ethnicity_dict = {}



for i in actor_data.index:
    actor_id = actor_data.at[i, 'ActorID']
    actor_age = actor_data.at[i, 'Age']
    actor_sex = actor_data.at[i, 'Sex']
    actor_race = actor_data.at[i, 'Race']
    actor_ethnicity = actor_data.at[i, 'Ethnicity']
    age_dict[actor_id] = actor_age
    sex_dict[actor_id] = actor_sex
    race_dict[actor_id] = actor_race
    ethnicity_dict[actor_id] = actor_ethnicity

# %%
# Get lists of characteristics in the order actors appear in mid_data_train:


age_list_train = []
sex_list_train = []
race_list_train = []
ethnicity_list_train = []


for j in mid_data_train.index:
    age = age_dict[mid_data_train.at[j, 'actorID']]
    age_list_train.append(age)
    
    sex = sex_dict[mid_data_train.at[j, 'actorID']]
    sex_list_train.append(sex)
    
    race = race_dict[mid_data_train.at[j, 'actorID']]
    race_list_train.append(race)
    
    ethnicity = ethnicity_dict[mid_data_train.at[j, 'actorID']]
    ethnicity_list_train.append(ethnicity)
    
# Get lists of characteristics in the order actors appear in mid_data_test:

#age_list_test = []
#sex_list_test = []
#race_list_test = []
#ethnicity_list_test = []


#for j in mid_data_test.index:
#    age = age_dict[mid_data_test.at[j, 'ActorID']]
#    age_list_test.append(age)
#    
#    sex = sex_dict[mid_data_test.at[j, 'ActorID']]
#    sex_list_test.append(sex)
#    
#    race = race_dict[mid_data_test.at[j, 'ActorID']]
#    race_list_test.append(race)
#    
#    ethnicity = ethnicity_dict[mid_data_test.at[j, 'ActorID']]
#    ethnicity_list_test.append(ethnicity)

# %%
mid_data_train
# Out:
#                FileID  actorID Emotion SentenceID  zcr_mean  energy_mean  \
# 0     1006_DFA_ANG_XX     1006     ANG        DFA  0.205303     0.026108
# 1     1006_DFA_DIS_XX     1006     DIS        DFA  0.142912     0.009082
# 2     1006_DFA_FEA_XX     1006     FEA        DFA  0.150361     0.023924
# 3     1006_DFA_HAP_XX     1006     HAP        DFA  0.117750     0.012498
# 4     1006_DFA_NEU_XX     1006     NEU        DFA  0.118134     0.016632
# ...               ...      ...     ...        ...       ...          ...
# 1195  1089_WSI_DIS_XX     1089     DIS        WSI  0.383122     0.012807
# 1196  1089_WSI_FEA_XX     1089     FEA        WSI  0.225401     0.012779
# 1197  1089_WSI_HAP_XX     1089     HAP        WSI  0.353292     0.010540
# 1198  1089_WSI_NEU_XX     1089     NEU        WSI  0.139094     0.008446
# 1199  1089_WSI_SAD_XX     1089     SAD        WSI  0.202795     0.015650
#
#       energy_entropy_mean  spectral_centroid_mean  spectral_spread_mean  \
# 0                2.936040                0.295857              0.220094
# 1                2.815900                0.227427              0.198710
# 2                2.758088                0.214044              0.187709
# 3                2.945889                0.220303              0.219790
# 4                2.802065                0.193803              0.183517
# ...                   ...                     ...                   ...
# 1195             2.857422                0.432665              0.261348
# 1196             2.743240                0.330818              0.259093
# 1197             2.755661                0.400803              0.235666
# 1198             2.883838                0.221700              0.209398
# 1199             2.767488                0.260258              0.209579
#
#       spectral_entropy_mean  ...  delta chroma_4_std  delta chroma_5_std  \
# 0                  1.819624  ...            0.009290            0.011798
# 1                  0.867856  ...            0.043360            0.034025
# 2                  0.842085  ...            0.016754            0.011521
# 3                  0.914615  ...            0.033142            0.021647
# 4                  0.747918  ...            0.026941            0.010169
# ...                     ...  ...                 ...                 ...
# 1195               1.914457  ...            0.004918            0.013561
# 1196               1.050608  ...            0.046939            0.049075
# 1197               1.358809  ...            0.016718            0.016632
# 1198               1.056357  ...            0.023018            0.010559
# 1199               0.879084  ...            0.031204            0.014621
#
#       delta chroma_6_std  delta chroma_7_std  delta chroma_8_std  \
# 0               0.012141            0.005553            0.001191
# 1               0.037411            0.016621            0.002165
# 2               0.040531            0.011855            0.010751
# 3               0.012535            0.028002            0.018135
# 4               0.038335            0.015219            0.011879
# ...                  ...                 ...                 ...
# 1195            0.010522            0.009827            0.005967
# 1196            0.040668            0.010523            0.001213
# 1197            0.026774            0.019348            0.003012
# 1198            0.011100            0.021006            0.007919
# 1199            0.020446            0.017638            0.005448
#
#       delta chroma_9_std  delta chroma_10_std  delta chroma_11_std  \
# 0               0.005477             0.013535             0.017165
# 1               0.006136             0.005255             0.008078
# 2               0.012277             0.005750             0.014204
# 3               0.012021             0.022196             0.020446
# 4               0.015302             0.008216             0.013460
# ...                  ...                  ...                  ...
# 1195            0.010294             0.010915             0.004520
# 1196            0.006301             0.013476             0.003387
# 1197            0.017886             0.012128             0.011175
# 1198            0.003927             0.009988             0.009861
# 1199            0.004618             0.011880             0.010401
#
#       delta chroma_12_std  delta chroma_std_std
# 0                0.008230              0.008214
# 1                0.006201              0.013113
# 2                0.013292              0.012245
# 3                0.008418              0.012261
# 4                0.016431              0.012039
# ...                   ...                   ...
# 1195             0.010917              0.005369
# 1196             0.001923              0.016563
# 1197             0.002991              0.008993
# 1198             0.020112              0.007493
# 1199             0.007154              0.009231
#
# [1200 rows x 140 columns]

# %%
# Add the characteristics columns to mid_data_train:


mid_data_train.insert(4, 'Age', age_list_train)
mid_data_train.insert(5, 'Sex', sex_list_train)
mid_data_train.insert(6, 'Race', race_list_train)
mid_data_train.insert(7, 'Ethnicity', ethnicity_list_train)

# %%
mid_data_train.head()
# Out:
#             FileID  actorID Emotion SentenceID  Age     Sex       Race  \
# 0  1006_DFA_ANG_XX     1006     ANG        DFA   58  Female  Caucasian
# 1  1006_DFA_DIS_XX     1006     DIS        DFA   58  Female  Caucasian
# 2  1006_DFA_FEA_XX     1006     FEA        DFA   58  Female  Caucasian
# 3  1006_DFA_HAP_XX     1006     HAP        DFA   58  Female  Caucasian
# 4  1006_DFA_NEU_XX     1006     NEU        DFA   58  Female  Caucasian
#
#       Ethnicity  zcr_mean  energy_mean  ...  delta chroma_4_std  \
# 0  Not Hispanic  0.205303     0.026108  ...            0.009290
# 1  Not Hispanic  0.142912     0.009082  ...            0.043360
# 2  Not Hispanic  0.150361     0.023924  ...            0.016754
# 3  Not Hispanic  0.117750     0.012498  ...            0.033142
# 4  Not Hispanic  0.118134     0.016632  ...            0.026941
#
#    delta chroma_5_std  delta chroma_6_std  delta chroma_7_std  \
# 0            0.011798            0.012141            0.005553
# 1            0.034025            0.037411            0.016621
# 2            0.011521            0.040531            0.011855
# 3            0.021647            0.012535            0.028002
# 4            0.010169            0.038335            0.015219
#
#    delta chroma_8_std  delta chroma_9_std  delta chroma_10_std  \
# 0            0.001191            0.005477             0.013535
# 1            0.002165            0.006136             0.005255
# 2            0.010751            0.012277             0.005750
# 3            0.018135            0.012021             0.022196
# 4            0.011879            0.015302             0.008216
#
#    delta chroma_11_std  delta chroma_12_std  delta chroma_std_std
# 0             0.017165             0.008230              0.008214
# 1             0.008078             0.006201              0.013113
# 2             0.014204             0.013292              0.012245
# 3             0.020446             0.008418              0.012261
# 4             0.013460             0.016431              0.012039
#
# [5 rows x 144 columns]

# %%
# Add the characteristics columns to mid_data_test:

#mid_data_test.insert(4, 'Age', age_list_test)
#mid_data_test.insert(5, 'Sex', sex_list_test)
#mid_data_test.insert(6, 'Race', race_list_test)
#mid_data_test.insert(7, 'Ethnicity', ethnicity_list_test)

# %%
#mid_data_test.head()

# %%
# Save the files to csv

mid_data_train.to_csv('midFeaturesTestFinalWithChars.csv', index=False)
#mid_data_test.to_csv('midFeaturesTestSetWithChars.csv', index=False)
