# %%
import os
import shutil, glob
import time
import pandas as pd

import numpy as np

# %% [markdown]
# ## Actor distribution
# Here I create a dataframe with the actor code, the sentence spoken, the emotion conveyed, and the intensity in each clip. I'll dump it in a .csv file so that we don't need to do this again.
#
# I also display the unique values in each column and count how many each one appears.

# %% [markdown]
# ## Part 0: Remove intensity
# Here I move the files with intensities to a new location

# %%
# Create new folder for the clips that have intensity
if not os.path.isdir('../../AudioWAV_Intensity'):
    os.mkdir('../../AudioWAV_Intensity')

folder = '../../AudioWAV'
files_intensity = glob.glob('%s/*_LO.wav' %folder)
files_intensity = files_intensity + glob.glob('%s/*_MD.wav' %folder)
files_intensity = files_intensity + glob.glob('%s/*_HI.wav' %folder)

for file in files_intensity:
    shutil.move(file, '../../AudioWAV_Intensity/')

# %% [markdown]
# ### First part: Without intensities
# I removed the files with intensities from the folder. Here I process only the files with unspecified intensity (XX).

# %%
files = os.listdir('../../AudioWAV')

time_start = time.time()
df = pd.DataFrame(columns = ['FileID', 'ActorID', 'SentenceID', 'Emotion', 'Intensity'],
                  dtype='category')

for file in files:
    fileID = file.split('.')[0]
    cats = fileID.split('_')
    
    new_row = pd.DataFrame([[fileID] + cats],
                        columns = ['FileID', 'ActorID', 'SentenceID', 'Emotion', 'Intensity'])
    df = pd.concat((df,new_row), axis=0, ignore_index=True)

# Turn columns into factors (except for FileID)
for col in df.columns:
    if col != 'FileID':
        df[col] = (df[col]).astype('category')

time_end = time.time()
time_total = time_end-time_start
print('Number of files: %i' %(len(files)))
if time_total <= 60:
    print('Duration: %f (s)' %time_total)
elif 60 < time_total <= 3600:
    print('Duration: %f (min)' %(time_total/60))
else:
    print('Duration: %f (h)' %(time_total/3600))
# Out:
# Number of files: 6077
# Duration: 4.497929 (s)

# %%
df.describe()
# Out:
#                  FileID ActorID SentenceID Emotion Intensity
# count              6077    6077       6077    6077      6077
# unique             6077      91         12       6         1
# top     1050_IWW_HAP_XX    1001        DFA     NEU        XX
# freq                  1      67        546    1087      6077

# %%
print('Actors:')
print(np.unique(df.ActorID))
print()
print('Sentence:')
print(np.unique(df.SentenceID))
print()
print('Emotions:')
print(np.unique(df.Emotion))
print()
print('Intensities:')
print(np.unique(df.Intensity))
# Out:
# Actors:
# ['1001' '1002' '1003' '1004' '1005' '1006' '1007' '1008' '1009' '1010'
#  '1011' '1012' '1013' '1014' '1015' '1016' '1017' '1018' '1019' '1020'
#  '1021' '1022' '1023' '1024' '1025' '1026' '1027' '1028' '1029' '1030'
#  '1031' '1032' '1033' '1034' '1035' '1036' '1037' '1038' '1039' '1040'
#  '1041' '1042' '1043' '1044' '1045' '1046' '1047' '1048' '1049' '1050'
#  '1051' '1052' '1053' '1054' '1055' '1056' '1057' '1058' '1059' '1060'
#  '1061' '1062' '1063' '1064' '1065' '1066' '1067' '1068' '1069' '1070'
#  '1071' '1072' '1073' '1074' '1075' '1076' '1077' '1078' '1079' '1080'
#  '1081' '1082' '1083' '1084' '1085' '1086' '1087' '1088' '1089' '1090'
#  '1091']
#
# Sentence:
# ['DFA' 'IEO' 'IOM' 'ITH' 'ITS' 'IWL' 'IWW' 'MTI' 'TAI' 'TIE' 'TSI' 'WSI']
#
# Emotions:
# ['ANG' 'DIS' 'FEA' 'HAP' 'NEU' 'SAD']
#
# Intensities:
# ['XX']

# %%
pd.set_option('display.max_rows', None)
print('ActorID')
print(df.ActorID.value_counts())
print()

print('SentenceID')
print(df.SentenceID.value_counts().sort_index())
print()

print('Emotion')
print(df.Emotion.value_counts().sort_index())
print()

print('Intensity')
print(df.Intensity.value_counts().sort_index())
print()
# Out:
# ActorID
# 1001    67
# 1047    67
# 1067    67
# 1066    67
# 1065    67
# 1064    67
# 1063    67
# 1062    67
# 1061    67
# 1060    67
# 1059    67
# 1058    67
# 1057    67
# 1056    67
# 1055    67
# 1054    67
# 1053    67
# 1052    67
# 1051    67
# 1050    67
# 1049    67
# 1068    67
# 1069    67
# 1070    67
# 1082    67
# 1090    67
# 1089    67
# 1088    67
# 1087    67
# 1086    67
# 1085    67
# 1084    67
# 1083    67
# 1081    67
# 1071    67
# 1080    67
# 1079    67
# 1078    67
# 1077    67
# 1075    67
# 1074    67
# 1073    67
# 1072    67
# 1048    67
# 1046    67
# 1023    67
# 1014    67
# 1045    67
# 1022    67
# 1021    67
# 1020    67
# 1018    67
# 1017    67
# 1016    67
# 1015    67
# 1013    67
# 1025    67
# 1012    67
# 1011    67
# 1010    67
# 1007    67
# 1006    67
# 1005    67
# 1004    67
# 1003    67
# 1024    67
# 1091    67
# 1026    67
# 1035    67
# 1044    67
# 1043    67
# 1042    67
# 1041    67
# 1040    67
# 1039    67
# 1038    67
# 1037    67
# 1027    67
# 1036    67
# 1034    67
# 1033    67
# 1032    67
# 1031    67
# 1030    67
# 1029    67
# 1028    67
# 1076    66
# 1002    66
# 1009    61
# 1008    61
# 1019    61
# Name: ActorID, dtype: int64
#
# SentenceID
# DFA    546
# IEO     91
# IOM    546
# ITH    540
# ITS    545
# IWL    546
# IWW    546
# MTI    540
# TAI    546
# TIE    545
# TSI    546
# WSI    540
# Name: SentenceID, dtype: int64
#
# Emotion
# ANG     998
# DIS     998
# FEA     998
# HAP     998
# NEU    1087
# SAD     998
# Name: Emotion, dtype: int64
#
# Intensity
# XX    6077
# Name: Intensity, dtype: int64

# %% [markdown]
# #### Important!
# The distribution of actors, sentences, and emotions is not completely uniform. There are some missing cilps, but those were already missing in the CREMA-D Github and Kaggle repositories. Nothing we can do, but we should know about this.

# %%
df.to_csv('Data/Categories.csv', index=False)

# %%
df
# Out:
#                FileID ActorID SentenceID Emotion Intensity
# 0     1001_DFA_ANG_XX    1001        DFA     ANG        XX
# 1     1001_DFA_DIS_XX    1001        DFA     DIS        XX
# 2     1001_DFA_FEA_XX    1001        DFA     FEA        XX
# 3     1001_DFA_HAP_XX    1001        DFA     HAP        XX
# 4     1001_DFA_NEU_XX    1001        DFA     NEU        XX
# 5     1001_DFA_SAD_XX    1001        DFA     SAD        XX
# 6     1001_IEO_NEU_XX    1001        IEO     NEU        XX
# 7     1001_IOM_ANG_XX    1001        IOM     ANG        XX
# 8     1001_IOM_DIS_XX    1001        IOM     DIS        XX
# 9     1001_IOM_FEA_XX    1001        IOM     FEA        XX
# 10    1001_IOM_HAP_XX    1001        IOM     HAP        XX
# 11    1001_IOM_NEU_XX    1001        IOM     NEU        XX
# 12    1001_IOM_SAD_XX    1001        IOM     SAD        XX
# 13    1001_ITH_ANG_XX    1001        ITH     ANG        XX
# 14    1001_ITH_DIS_XX    1001        ITH     DIS        XX
# 15    1001_ITH_FEA_XX    1001        ITH     FEA        XX
# 16    1001_ITH_HAP_XX    1001        ITH     HAP        XX
# 17    1001_ITH_NEU_XX    1001        ITH     NEU        XX
# 18    1001_ITH_SAD_XX    1001        ITH     SAD        XX
# 19    1001_ITS_ANG_XX    1001        ITS     ANG        XX
# 20    1001_ITS_DIS_XX    1001        ITS     DIS        XX
# 21    1001_ITS_FEA_XX    1001        ITS     FEA        XX
# 22    1001_ITS_HAP_XX    1001        ITS     HAP        XX
# 23    1001_ITS_NEU_XX    1001        ITS     NEU        XX
# 24    1001_ITS_SAD_XX    1001        ITS     SAD        XX
# 25    1001_IWL_ANG_XX    1001        IWL     ANG        XX
# 26    1001_IWL_DIS_XX    1001        IWL     DIS        XX
# 27    1001_IWL_FEA_XX    1001        IWL     FEA        XX
# 28    1001_IWL_HAP_XX    1001        IWL     HAP        XX
# 29    1001_IWL_NEU_XX    1001        IWL     NEU        XX
# 30    1001_IWL_SAD_XX    1001        IWL     SAD        XX
# 31    1001_IWW_ANG_XX    1001        IWW     ANG        XX
# 32    1001_IWW_DIS_XX    1001        IWW     DIS        XX
# 33    1001_IWW_FEA_XX    1001        IWW     FEA        XX
# 34    1001_IWW_HAP_XX    1001        IWW     HAP        XX
# 35    1001_IWW_NEU_XX    1001        IWW     NEU        XX
# 36    1001_IWW_SAD_XX    1001        IWW     SAD        XX
# 37    1001_MTI_ANG_XX    1001        MTI     ANG        XX
# 38    1001_MTI_DIS_XX    1001        MTI     DIS        XX
# 39    1001_MTI_FEA_XX    1001        MTI     FEA        XX
# 40    1001_MTI_HAP_XX    1001        MTI     HAP        XX
# 41    1001_MTI_NEU_XX    1001        MTI     NEU        XX
# 42    1001_MTI_SAD_XX    1001        MTI     SAD        XX
# 43    1001_TAI_ANG_XX    1001        TAI     ANG        XX
# 44    1001_TAI_DIS_XX    1001        TAI     DIS        XX
# 45    1001_TAI_FEA_XX    1001        TAI     FEA        XX
# 46    1001_TAI_HAP_XX    1001        TAI     HAP        XX
# 47    1001_TAI_NEU_XX    1001        TAI     NEU        XX
# 48    1001_TAI_SAD_XX    1001        TAI     SAD        XX
# 49    1001_TIE_ANG_XX    1001        TIE     ANG        XX
# 50    1001_TIE_DIS_XX    1001        TIE     DIS        XX
# 51    1001_TIE_FEA_XX    1001        TIE     FEA        XX
# 52    1001_TIE_HAP_XX    1001        TIE     HAP        XX
# 53    1001_TIE_NEU_XX    1001        TIE     NEU        XX
# 54    1001_TIE_SAD_XX    1001        TIE     SAD        XX
# 55    1001_TSI_ANG_XX    1001        TSI     ANG        XX
# 56    1001_TSI_DIS_XX    1001        TSI     DIS        XX
# 57    1001_TSI_FEA_XX    1001        TSI     FEA        XX
# 58    1001_TSI_HAP_XX    1001        TSI     HAP        XX
# 59    1001_TSI_NEU_XX    1001        TSI     NEU        XX
# 60    1001_TSI_SAD_XX    1001        TSI     SAD        XX
# 61    1001_WSI_ANG_XX    1001        WSI     ANG        XX
# 62    1001_WSI_DIS_XX    1001        WSI     DIS        XX
# 63    1001_WSI_FEA_XX    1001        WSI     FEA        XX
# 64    1001_WSI_HAP_XX    1001        WSI     HAP        XX
# 65    1001_WSI_NEU_XX    1001        WSI     NEU        XX
# 66    1001_WSI_SAD_XX    1001        WSI     SAD        XX
# 67    1002_DFA_ANG_XX    1002        DFA     ANG        XX
# 68    1002_DFA_DIS_XX    1002        DFA     DIS        XX
# 69    1002_DFA_FEA_XX    1002        DFA     FEA        XX
# 70    1002_DFA_HAP_XX    1002        DFA     HAP        XX
# 71    1002_DFA_NEU_XX    1002        DFA     NEU        XX
# 72    1002_DFA_SAD_XX    1002        DFA     SAD        XX
# 73    1002_IEO_NEU_XX    1002        IEO     NEU        XX
# 74    1002_IOM_ANG_XX    1002        IOM     ANG        XX
# 75    1002_IOM_DIS_XX    1002        IOM     DIS        XX
# 76    1002_IOM_FEA_XX    1002        IOM     FEA        XX
# 77    1002_IOM_HAP_XX    1002        IOM     HAP        XX
# 78    1002_IOM_NEU_XX    1002        IOM     NEU        XX
# 79    1002_IOM_SAD_XX    1002        IOM     SAD        XX
# 80    1002_ITH_ANG_XX    1002        ITH     ANG        XX
# 81    1002_ITH_DIS_XX    1002        ITH     DIS        XX
# 82    1002_ITH_FEA_XX    1002        ITH     FEA        XX
# 83    1002_ITH_HAP_XX    1002        ITH     HAP        XX
# 84    1002_ITH_NEU_XX    1002        ITH     NEU        XX
# 85    1002_ITH_SAD_XX    1002        ITH     SAD        XX
# 86    1002_ITS_ANG_XX    1002        ITS     ANG        XX
# 87    1002_ITS_DIS_XX    1002        ITS     DIS        XX
# 88    1002_ITS_FEA_XX    1002        ITS     FEA        XX
# 89    1002_ITS_HAP_XX    1002        ITS     HAP        XX
# 90    1002_ITS_NEU_XX    1002        ITS     NEU        XX
# 91    1002_ITS_SAD_XX    1002        ITS     SAD        XX
# 92    1002_IWL_ANG_XX    1002        IWL     ANG        XX
# 93    1002_IWL_DIS_XX    1002        IWL     DIS        XX
# 94    1002_IWL_FEA_XX    1002        IWL     FEA        XX
# 95    1002_IWL_HAP_XX    1002        IWL     HAP        XX
# 96    1002_IWL_NEU_XX    1002        IWL     NEU        XX
# 97    1002_IWL_SAD_XX    1002        IWL     SAD        XX
# 98    1002_IWW_ANG_XX    1002        IWW     ANG        XX
# 99    1002_IWW_DIS_XX    1002        IWW     DIS        XX
# 100   1002_IWW_FEA_XX    1002        IWW     FEA        XX
# 101   1002_IWW_HAP_XX    1002        IWW     HAP        XX
# 102   1002_IWW_NEU_XX    1002        IWW     NEU        XX
# 103   1002_IWW_SAD_XX    1002        IWW     SAD        XX
# 104   1002_MTI_ANG_XX    1002        MTI     ANG        XX
# 105   1002_MTI_DIS_XX    1002        MTI     DIS        XX
# 106   1002_MTI_FEA_XX    1002        MTI     FEA        XX
# 107   1002_MTI_HAP_XX    1002        MTI     HAP        XX
# 108   1002_MTI_NEU_XX    1002        MTI     NEU        XX
# 109   1002_MTI_SAD_XX    1002        MTI     SAD        XX
# 110   1002_TAI_ANG_XX    1002        TAI     ANG        XX
# 111   1002_TAI_DIS_XX    1002        TAI     DIS        XX
# 112   1002_TAI_FEA_XX    1002        TAI     FEA        XX
# 113   1002_TAI_HAP_XX    1002        TAI     HAP        XX
# 114   1002_TAI_NEU_XX    1002        TAI     NEU        XX
# 115   1002_TAI_SAD_XX    1002        TAI     SAD        XX
# 116   1002_TIE_ANG_XX    1002        TIE     ANG        XX
# 117   1002_TIE_DIS_XX    1002        TIE     DIS        XX
# 118   1002_TIE_FEA_XX    1002        TIE     FEA        XX
# 119   1002_TIE_HAP_XX    1002        TIE     HAP        XX
# 120   1002_TIE_SAD_XX    1002        TIE     SAD        XX
# 121   1002_TSI_ANG_XX    1002        TSI     ANG        XX
# 122   1002_TSI_DIS_XX    1002        TSI     DIS        XX
# 123   1002_TSI_FEA_XX    1002        TSI     FEA        XX
# 124   1002_TSI_HAP_XX    1002        TSI     HAP        XX
# 125   1002_TSI_NEU_XX    1002        TSI     NEU        XX
# 126   1002_TSI_SAD_XX    1002        TSI     SAD        XX
# 127   1002_WSI_ANG_XX    1002        WSI     ANG        XX
# 128   1002_WSI_DIS_XX    1002        WSI     DIS        XX
# 129   1002_WSI_FEA_XX    1002        WSI     FEA        XX
# 130   1002_WSI_HAP_XX    1002        WSI     HAP        XX
# 131   1002_WSI_NEU_XX    1002        WSI     NEU        XX
# 132   1002_WSI_SAD_XX    1002        WSI     SAD        XX
# 133   1003_DFA_ANG_XX    1003        DFA     ANG        XX
# 134   1003_DFA_DIS_XX    1003        DFA     DIS        XX
# 135   1003_DFA_FEA_XX    1003        DFA     FEA        XX
# 136   1003_DFA_HAP_XX    1003        DFA     HAP        XX
# 137   1003_DFA_NEU_XX    1003        DFA     NEU        XX
# 138   1003_DFA_SAD_XX    1003        DFA     SAD        XX
# 139   1003_IEO_NEU_XX    1003        IEO     NEU        XX
# 140   1003_IOM_ANG_XX    1003        IOM     ANG        XX
# 141   1003_IOM_DIS_XX    1003        IOM     DIS        XX
# 142   1003_IOM_FEA_XX    1003        IOM     FEA        XX
# 143   1003_IOM_HAP_XX    1003        IOM     HAP        XX
# 144   1003_IOM_NEU_XX    1003        IOM     NEU        XX
# 145   1003_IOM_SAD_XX    1003        IOM     SAD        XX
# 146   1003_ITH_ANG_XX    1003        ITH     ANG        XX
# 147   1003_ITH_DIS_XX    1003        ITH     DIS        XX
# 148   1003_ITH_FEA_XX    1003        ITH     FEA        XX
# 149   1003_ITH_HAP_XX    1003        ITH     HAP        XX
# 150   1003_ITH_NEU_XX    1003        ITH     NEU        XX
# 151   1003_ITH_SAD_XX    1003        ITH     SAD        XX
# 152   1003_ITS_ANG_XX    1003        ITS     ANG        XX
# 153   1003_ITS_DIS_XX    1003        ITS     DIS        XX
# 154   1003_ITS_FEA_XX    1003        ITS     FEA        XX
# 155   1003_ITS_HAP_XX    1003        ITS     HAP        XX
# 156   1003_ITS_NEU_XX    1003        ITS     NEU        XX
# 157   1003_ITS_SAD_XX    1003        ITS     SAD        XX
# 158   1003_IWL_ANG_XX    1003        IWL     ANG        XX
# 159   1003_IWL_DIS_XX    1003        IWL     DIS        XX
# 160   1003_IWL_FEA_XX    1003        IWL     FEA        XX
# 161   1003_IWL_HAP_XX    1003        IWL     HAP        XX
# 162   1003_IWL_NEU_XX    1003        IWL     NEU        XX
# 163   1003_IWL_SAD_XX    1003        IWL     SAD        XX
# 164   1003_IWW_ANG_XX    1003        IWW     ANG        XX
# 165   1003_IWW_DIS_XX    1003        IWW     DIS        XX
# 166   1003_IWW_FEA_XX    1003        IWW     FEA        XX
# 167   1003_IWW_HAP_XX    1003        IWW     HAP        XX
# 168   1003_IWW_NEU_XX    1003        IWW     NEU        XX
# 169   1003_IWW_SAD_XX    1003        IWW     SAD        XX
# 170   1003_MTI_ANG_XX    1003        MTI     ANG        XX
# 171   1003_MTI_DIS_XX    1003        MTI     DIS        XX
# 172   1003_MTI_FEA_XX    1003        MTI     FEA        XX
# 173   1003_MTI_HAP_XX    1003        MTI     HAP        XX
# 174   1003_MTI_NEU_XX    1003        MTI     NEU        XX
# 175   1003_MTI_SAD_XX    1003        MTI     SAD        XX
# 176   1003_TAI_ANG_XX    1003        TAI     ANG        XX
# 177   1003_TAI_DIS_XX    1003        TAI     DIS        XX
# 178   1003_TAI_FEA_XX    1003        TAI     FEA        XX
# 179   1003_TAI_HAP_XX    1003        TAI     HAP        XX
# 180   1003_TAI_NEU_XX    1003        TAI     NEU        XX
# 181   1003_TAI_SAD_XX    1003        TAI     SAD        XX
# 182   1003_TIE_ANG_XX    1003        TIE     ANG        XX
# 183   1003_TIE_DIS_XX    1003        TIE     DIS        XX
# 184   1003_TIE_FEA_XX    1003        TIE     FEA        XX
# 185   1003_TIE_HAP_XX    1003        TIE     HAP        XX
# 186   1003_TIE_NEU_XX    1003        TIE     NEU        XX
# 187   1003_TIE_SAD_XX    1003        TIE     SAD        XX
# 188   1003_TSI_ANG_XX    1003        TSI     ANG        XX
# 189   1003_TSI_DIS_XX    1003        TSI     DIS        XX
# 190   1003_TSI_FEA_XX    1003        TSI     FEA        XX
# 191   1003_TSI_HAP_XX    1003        TSI     HAP        XX
# 192   1003_TSI_NEU_XX    1003        TSI     NEU        XX
# 193   1003_TSI_SAD_XX    1003        TSI     SAD        XX
# 194   1003_WSI_ANG_XX    1003        WSI     ANG        XX
# 195   1003_WSI_DIS_XX    1003        WSI     DIS        XX
# 196   1003_WSI_FEA_XX    1003        WSI     FEA        XX
# 197   1003_WSI_HAP_XX    1003        WSI     HAP        XX
# 198   1003_WSI_NEU_XX    1003        WSI     NEU        XX
# 199   1003_WSI_SAD_XX    1003        WSI     SAD        XX
# 200   1004_DFA_ANG_XX    1004        DFA     ANG        XX
# 201   1004_DFA_DIS_XX    1004        DFA     DIS        XX
# 202   1004_DFA_FEA_XX    1004        DFA     FEA        XX
# 203   1004_DFA_HAP_XX    1004        DFA     HAP        XX
# 204   1004_DFA_NEU_XX    1004        DFA     NEU        XX
# 205   1004_DFA_SAD_XX    1004        DFA     SAD        XX
# 206   1004_IEO_NEU_XX    1004        IEO     NEU        XX
# 207   1004_IOM_ANG_XX    1004        IOM     ANG        XX
# 208   1004_IOM_DIS_XX    1004        IOM     DIS        XX
# 209   1004_IOM_FEA_XX    1004        IOM     FEA        XX
# 210   1004_IOM_HAP_XX    1004        IOM     HAP        XX
# 211   1004_IOM_NEU_XX    1004        IOM     NEU        XX
# 212   1004_IOM_SAD_XX    1004        IOM     SAD        XX
# 213   1004_ITH_ANG_XX    1004        ITH     ANG        XX
# 214   1004_ITH_DIS_XX    1004        ITH     DIS        XX
# 215   1004_ITH_FEA_XX    1004        ITH     FEA        XX
# 216   1004_ITH_HAP_XX    1004        ITH     HAP        XX
# 217   1004_ITH_NEU_XX    1004        ITH     NEU        XX
# 218   1004_ITH_SAD_XX    1004        ITH     SAD        XX
# 219   1004_ITS_ANG_XX    1004        ITS     ANG        XX
# 220   1004_ITS_DIS_XX    1004        ITS     DIS        XX
# 221   1004_ITS_FEA_XX    1004        ITS     FEA        XX
# 222   1004_ITS_HAP_XX    1004        ITS     HAP        XX
# 223   1004_ITS_NEU_XX    1004        ITS     NEU        XX
# 224   1004_ITS_SAD_XX    1004        ITS     SAD        XX
# 225   1004_IWL_ANG_XX    1004        IWL     ANG        XX
# 226   1004_IWL_DIS_XX    1004        IWL     DIS        XX
# 227   1004_IWL_FEA_XX    1004        IWL     FEA        XX
# 228   1004_IWL_HAP_XX    1004        IWL     HAP        XX
# 229   1004_IWL_NEU_XX    1004        IWL     NEU        XX
# 230   1004_IWL_SAD_XX    1004        IWL     SAD        XX
# 231   1004_IWW_ANG_XX    1004        IWW     ANG        XX
# 232   1004_IWW_DIS_XX    1004        IWW     DIS        XX
# 233   1004_IWW_FEA_XX    1004        IWW     FEA        XX
# 234   1004_IWW_HAP_XX    1004        IWW     HAP        XX
# 235   1004_IWW_NEU_XX    1004        IWW     NEU        XX
# 236   1004_IWW_SAD_XX    1004        IWW     SAD        XX
# 237   1004_MTI_ANG_XX    1004        MTI     ANG        XX
# 238   1004_MTI_DIS_XX    1004        MTI     DIS        XX
# 239   1004_MTI_FEA_XX    1004        MTI     FEA        XX
# 240   1004_MTI_HAP_XX    1004        MTI     HAP        XX
# 241   1004_MTI_NEU_XX    1004        MTI     NEU        XX
# 242   1004_MTI_SAD_XX    1004        MTI     SAD        XX
# 243   1004_TAI_ANG_XX    1004        TAI     ANG        XX
# 244   1004_TAI_DIS_XX    1004        TAI     DIS        XX
# 245   1004_TAI_FEA_XX    1004        TAI     FEA        XX
# 246   1004_TAI_HAP_XX    1004        TAI     HAP        XX
# 247   1004_TAI_NEU_XX    1004        TAI     NEU        XX
# 248   1004_TAI_SAD_XX    1004        TAI     SAD        XX
# 249   1004_TIE_ANG_XX    1004        TIE     ANG        XX
# 250   1004_TIE_DIS_XX    1004        TIE     DIS        XX
# 251   1004_TIE_FEA_XX    1004        TIE     FEA        XX
# 252   1004_TIE_HAP_XX    1004        TIE     HAP        XX
# 253   1004_TIE_NEU_XX    1004        TIE     NEU        XX
# 254   1004_TIE_SAD_XX    1004        TIE     SAD        XX
# 255   1004_TSI_ANG_XX    1004        TSI     ANG        XX
# 256   1004_TSI_DIS_XX    1004        TSI     DIS        XX
# 257   1004_TSI_FEA_XX    1004        TSI     FEA        XX
# 258   1004_TSI_HAP_XX    1004        TSI     HAP        XX
# 259   1004_TSI_NEU_XX    1004        TSI     NEU        XX
# 260   1004_TSI_SAD_XX    1004        TSI     SAD        XX
# 261   1004_WSI_ANG_XX    1004        WSI     ANG        XX
# 262   1004_WSI_DIS_XX    1004        WSI     DIS        XX
# 263   1004_WSI_FEA_XX    1004        WSI     FEA        XX
# 264   1004_WSI_HAP_XX    1004        WSI     HAP        XX
# 265   1004_WSI_NEU_XX    1004        WSI     NEU        XX
# 266   1004_WSI_SAD_XX    1004        WSI     SAD        XX
# 267   1005_DFA_ANG_XX    1005        DFA     ANG        XX
# 268   1005_DFA_DIS_XX    1005        DFA     DIS        XX
# 269   1005_DFA_FEA_XX    1005        DFA     FEA        XX
# 270   1005_DFA_HAP_XX    1005        DFA     HAP        XX
# 271   1005_DFA_NEU_XX    1005        DFA     NEU        XX
# 272   1005_DFA_SAD_XX    1005        DFA     SAD        XX
# 273   1005_IEO_NEU_XX    1005        IEO     NEU        XX
# 274   1005_IOM_ANG_XX    1005        IOM     ANG        XX
# 275   1005_IOM_DIS_XX    1005        IOM     DIS        XX
# 276   1005_IOM_FEA_XX    1005        IOM     FEA        XX
# 277   1005_IOM_HAP_XX    1005        IOM     HAP        XX
# 278   1005_IOM_NEU_XX    1005        IOM     NEU        XX
# 279   1005_IOM_SAD_XX    1005        IOM     SAD        XX
# 280   1005_ITH_ANG_XX    1005        ITH     ANG        XX
# 281   1005_ITH_DIS_XX    1005        ITH     DIS        XX
# 282   1005_ITH_FEA_XX    1005        ITH     FEA        XX
# 283   1005_ITH_HAP_XX    1005        ITH     HAP        XX
# 284   1005_ITH_NEU_XX    1005        ITH     NEU        XX
# 285   1005_ITH_SAD_XX    1005        ITH     SAD        XX
# 286   1005_ITS_ANG_XX    1005        ITS     ANG        XX
# 287   1005_ITS_DIS_XX    1005        ITS     DIS        XX
# 288   1005_ITS_FEA_XX    1005        ITS     FEA        XX
# 289   1005_ITS_HAP_XX    1005        ITS     HAP        XX
# 290   1005_ITS_NEU_XX    1005        ITS     NEU        XX
# 291   1005_ITS_SAD_XX    1005        ITS     SAD        XX
# 292   1005_IWL_ANG_XX    1005        IWL     ANG        XX
# 293   1005_IWL_DIS_XX    1005        IWL     DIS        XX
# 294   1005_IWL_FEA_XX    1005        IWL     FEA        XX
# 295   1005_IWL_HAP_XX    1005        IWL     HAP        XX
# 296   1005_IWL_NEU_XX    1005        IWL     NEU        XX
# 297   1005_IWL_SAD_XX    1005        IWL     SAD        XX
# 298   1005_IWW_ANG_XX    1005        IWW     ANG        XX
# 299   1005_IWW_DIS_XX    1005        IWW     DIS        XX
# 300   1005_IWW_FEA_XX    1005        IWW     FEA        XX
# 301   1005_IWW_HAP_XX    1005        IWW     HAP        XX
# 302   1005_IWW_NEU_XX    1005        IWW     NEU        XX
# 303   1005_IWW_SAD_XX    1005        IWW     SAD        XX
# 304   1005_MTI_ANG_XX    1005        MTI     ANG        XX
# 305   1005_MTI_DIS_XX    1005        MTI     DIS        XX
# 306   1005_MTI_FEA_XX    1005        MTI     FEA        XX
# 307   1005_MTI_HAP_XX    1005        MTI     HAP        XX
# 308   1005_MTI_NEU_XX    1005        MTI     NEU        XX
# 309   1005_MTI_SAD_XX    1005        MTI     SAD        XX
# 310   1005_TAI_ANG_XX    1005        TAI     ANG        XX
# 311   1005_TAI_DIS_XX    1005        TAI     DIS        XX
# 312   1005_TAI_FEA_XX    1005        TAI     FEA        XX
# 313   1005_TAI_HAP_XX    1005        TAI     HAP        XX
# 314   1005_TAI_NEU_XX    1005        TAI     NEU        XX
# 315   1005_TAI_SAD_XX    1005        TAI     SAD        XX
# 316   1005_TIE_ANG_XX    1005        TIE     ANG        XX
# 317   1005_TIE_DIS_XX    1005        TIE     DIS        XX
# 318   1005_TIE_FEA_XX    1005        TIE     FEA        XX
# 319   1005_TIE_HAP_XX    1005        TIE     HAP        XX
# 320   1005_TIE_NEU_XX    1005        TIE     NEU        XX
# 321   1005_TIE_SAD_XX    1005        TIE     SAD        XX
# 322   1005_TSI_ANG_XX    1005        TSI     ANG        XX
# 323   1005_TSI_DIS_XX    1005        TSI     DIS        XX
# 324   1005_TSI_FEA_XX    1005        TSI     FEA        XX
# 325   1005_TSI_HAP_XX    1005        TSI     HAP        XX
# 326   1005_TSI_NEU_XX    1005        TSI     NEU        XX
# 327   1005_TSI_SAD_XX    1005        TSI     SAD        XX
# 328   1005_WSI_ANG_XX    1005        WSI     ANG        XX
# 329   1005_WSI_DIS_XX    1005        WSI     DIS        XX
# 330   1005_WSI_FEA_XX    1005        WSI     FEA        XX
# 331   1005_WSI_HAP_XX    1005        WSI     HAP        XX
# 332   1005_WSI_NEU_XX    1005        WSI     NEU        XX
# 333   1005_WSI_SAD_XX    1005        WSI     SAD        XX
# 334   1006_DFA_ANG_XX    1006        DFA     ANG        XX
# 335   1006_DFA_DIS_XX    1006        DFA     DIS        XX
# 336   1006_DFA_FEA_XX    1006        DFA     FEA        XX
# 337   1006_DFA_HAP_XX    1006        DFA     HAP        XX
# 338   1006_DFA_NEU_XX    1006        DFA     NEU        XX
# 339   1006_DFA_SAD_XX    1006        DFA     SAD        XX
# 340   1006_IEO_NEU_XX    1006        IEO     NEU        XX
# 341   1006_IOM_ANG_XX    1006        IOM     ANG        XX
# 342   1006_IOM_DIS_XX    1006        IOM     DIS        XX
# 343   1006_IOM_FEA_XX    1006        IOM     FEA        XX
# 344   1006_IOM_HAP_XX    1006        IOM     HAP        XX
# 345   1006_IOM_NEU_XX    1006        IOM     NEU        XX
# 346   1006_IOM_SAD_XX    1006        IOM     SAD        XX
# 347   1006_ITH_ANG_XX    1006        ITH     ANG        XX
# 348   1006_ITH_DIS_XX    1006        ITH     DIS        XX
# 349   1006_ITH_FEA_XX    1006        ITH     FEA        XX
# 350   1006_ITH_HAP_XX    1006        ITH     HAP        XX
# 351   1006_ITH_NEU_XX    1006        ITH     NEU        XX
# 352   1006_ITH_SAD_XX    1006        ITH     SAD        XX
# 353   1006_ITS_ANG_XX    1006        ITS     ANG        XX
# 354   1006_ITS_DIS_XX    1006        ITS     DIS        XX
# 355   1006_ITS_FEA_XX    1006        ITS     FEA        XX
# 356   1006_ITS_HAP_XX    1006        ITS     HAP        XX
# 357   1006_ITS_NEU_XX    1006        ITS     NEU        XX
# 358   1006_ITS_SAD_XX    1006        ITS     SAD        XX
# 359   1006_IWL_ANG_XX    1006        IWL     ANG        XX
# 360   1006_IWL_DIS_XX    1006        IWL     DIS        XX
# 361   1006_IWL_FEA_XX    1006        IWL     FEA        XX
# 362   1006_IWL_HAP_XX    1006        IWL     HAP        XX
# 363   1006_IWL_NEU_XX    1006        IWL     NEU        XX
# 364   1006_IWL_SAD_XX    1006        IWL     SAD        XX
# 365   1006_IWW_ANG_XX    1006        IWW     ANG        XX
# 366   1006_IWW_DIS_XX    1006        IWW     DIS        XX
# 367   1006_IWW_FEA_XX    1006        IWW     FEA        XX
# 368   1006_IWW_HAP_XX    1006        IWW     HAP        XX
# 369   1006_IWW_NEU_XX    1006        IWW     NEU        XX
# 370   1006_IWW_SAD_XX    1006        IWW     SAD        XX
# 371   1006_MTI_ANG_XX    1006        MTI     ANG        XX
# 372   1006_MTI_DIS_XX    1006        MTI     DIS        XX
# 373   1006_MTI_FEA_XX    1006        MTI     FEA        XX
# 374   1006_MTI_HAP_XX    1006        MTI     HAP        XX
# 375   1006_MTI_NEU_XX    1006        MTI     NEU        XX
# 376   1006_MTI_SAD_XX    1006        MTI     SAD        XX
# 377   1006_TAI_ANG_XX    1006        TAI     ANG        XX
# 378   1006_TAI_DIS_XX    1006        TAI     DIS        XX
# 379   1006_TAI_FEA_XX    1006        TAI     FEA        XX
# 380   1006_TAI_HAP_XX    1006        TAI     HAP        XX
# 381   1006_TAI_NEU_XX    1006        TAI     NEU        XX
# 382   1006_TAI_SAD_XX    1006        TAI     SAD        XX
# 383   1006_TIE_ANG_XX    1006        TIE     ANG        XX
# 384   1006_TIE_DIS_XX    1006        TIE     DIS        XX
# 385   1006_TIE_FEA_XX    1006        TIE     FEA        XX
# 386   1006_TIE_HAP_XX    1006        TIE     HAP        XX
# 387   1006_TIE_NEU_XX    1006        TIE     NEU        XX
# 388   1006_TIE_SAD_XX    1006        TIE     SAD        XX
# 389   1006_TSI_ANG_XX    1006        TSI     ANG        XX
# 390   1006_TSI_DIS_XX    1006        TSI     DIS        XX
# 391   1006_TSI_FEA_XX    1006        TSI     FEA        XX
# 392   1006_TSI_HAP_XX    1006        TSI     HAP        XX
# 393   1006_TSI_NEU_XX    1006        TSI     NEU        XX
# 394   1006_TSI_SAD_XX    1006        TSI     SAD        XX
# 395   1006_WSI_ANG_XX    1006        WSI     ANG        XX
# 396   1006_WSI_DIS_XX    1006        WSI     DIS        XX
# 397   1006_WSI_FEA_XX    1006        WSI     FEA        XX
# 398   1006_WSI_HAP_XX    1006        WSI     HAP        XX
# 399   1006_WSI_NEU_XX    1006        WSI     NEU        XX
# 400   1006_WSI_SAD_XX    1006        WSI     SAD        XX
# 401   1007_DFA_ANG_XX    1007        DFA     ANG        XX
# 402   1007_DFA_DIS_XX    1007        DFA     DIS        XX
# 403   1007_DFA_FEA_XX    1007        DFA     FEA        XX
# 404   1007_DFA_HAP_XX    1007        DFA     HAP        XX
# 405   1007_DFA_NEU_XX    1007        DFA     NEU        XX
# 406   1007_DFA_SAD_XX    1007        DFA     SAD        XX
# 407   1007_IEO_NEU_XX    1007        IEO     NEU        XX
# 408   1007_IOM_ANG_XX    1007        IOM     ANG        XX
# 409   1007_IOM_DIS_XX    1007        IOM     DIS        XX
# 410   1007_IOM_FEA_XX    1007        IOM     FEA        XX
# 411   1007_IOM_HAP_XX    1007        IOM     HAP        XX
# 412   1007_IOM_NEU_XX    1007        IOM     NEU        XX
# 413   1007_IOM_SAD_XX    1007        IOM     SAD        XX
# 414   1007_ITH_ANG_XX    1007        ITH     ANG        XX
# 415   1007_ITH_DIS_XX    1007        ITH     DIS        XX
# 416   1007_ITH_FEA_XX    1007        ITH     FEA        XX
# 417   1007_ITH_HAP_XX    1007        ITH     HAP        XX
# 418   1007_ITH_NEU_XX    1007        ITH     NEU        XX
# 419   1007_ITH_SAD_XX    1007        ITH     SAD        XX
# 420   1007_ITS_ANG_XX    1007        ITS     ANG        XX
# 421   1007_ITS_DIS_XX    1007        ITS     DIS        XX
# 422   1007_ITS_FEA_XX    1007        ITS     FEA        XX
# 423   1007_ITS_HAP_XX    1007        ITS     HAP        XX
# 424   1007_ITS_NEU_XX    1007        ITS     NEU        XX
# 425   1007_ITS_SAD_XX    1007        ITS     SAD        XX
# 426   1007_IWL_ANG_XX    1007        IWL     ANG        XX
# 427   1007_IWL_DIS_XX    1007        IWL     DIS        XX
# 428   1007_IWL_FEA_XX    1007        IWL     FEA        XX
# 429   1007_IWL_HAP_XX    1007        IWL     HAP        XX
# 430   1007_IWL_NEU_XX    1007        IWL     NEU        XX
# 431   1007_IWL_SAD_XX    1007        IWL     SAD        XX
# 432   1007_IWW_ANG_XX    1007        IWW     ANG        XX
# 433   1007_IWW_DIS_XX    1007        IWW     DIS        XX
# 434   1007_IWW_FEA_XX    1007        IWW     FEA        XX
# 435   1007_IWW_HAP_XX    1007        IWW     HAP        XX
# 436   1007_IWW_NEU_XX    1007        IWW     NEU        XX
# 437   1007_IWW_SAD_XX    1007        IWW     SAD        XX
# 438   1007_MTI_ANG_XX    1007        MTI     ANG        XX
# 439   1007_MTI_DIS_XX    1007        MTI     DIS        XX
# 440   1007_MTI_FEA_XX    1007        MTI     FEA        XX
# 441   1007_MTI_HAP_XX    1007        MTI     HAP        XX
# 442   1007_MTI_NEU_XX    1007        MTI     NEU        XX
# 443   1007_MTI_SAD_XX    1007        MTI     SAD        XX
# 444   1007_TAI_ANG_XX    1007        TAI     ANG        XX
# 445   1007_TAI_DIS_XX    1007        TAI     DIS        XX
# 446   1007_TAI_FEA_XX    1007        TAI     FEA        XX
# 447   1007_TAI_HAP_XX    1007        TAI     HAP        XX
# 448   1007_TAI_NEU_XX    1007        TAI     NEU        XX
# 449   1007_TAI_SAD_XX    1007        TAI     SAD        XX
# 450   1007_TIE_ANG_XX    1007        TIE     ANG        XX
# 451   1007_TIE_DIS_XX    1007        TIE     DIS        XX
# 452   1007_TIE_FEA_XX    1007        TIE     FEA        XX
# 453   1007_TIE_HAP_XX    1007        TIE     HAP        XX
# 454   1007_TIE_NEU_XX    1007        TIE     NEU        XX
# 455   1007_TIE_SAD_XX    1007        TIE     SAD        XX
# 456   1007_TSI_ANG_XX    1007        TSI     ANG        XX
# 457   1007_TSI_DIS_XX    1007        TSI     DIS        XX
# 458   1007_TSI_FEA_XX    1007        TSI     FEA        XX
# 459   1007_TSI_HAP_XX    1007        TSI     HAP        XX
# 460   1007_TSI_NEU_XX    1007        TSI     NEU        XX
# 461   1007_TSI_SAD_XX    1007        TSI     SAD        XX
# 462   1007_WSI_ANG_XX    1007        WSI     ANG        XX
# 463   1007_WSI_DIS_XX    1007        WSI     DIS        XX
# 464   1007_WSI_FEA_XX    1007        WSI     FEA        XX
# 465   1007_WSI_HAP_XX    1007        WSI     HAP        XX
# 466   1007_WSI_NEU_XX    1007        WSI     NEU        XX
# 467   1007_WSI_SAD_XX    1007        WSI     SAD        XX
# 468   1008_DFA_ANG_XX    1008        DFA     ANG        XX
# 469   1008_DFA_DIS_XX    1008        DFA     DIS        XX
# 470   1008_DFA_FEA_XX    1008        DFA     FEA        XX
# 471   1008_DFA_HAP_XX    1008        DFA     HAP        XX
# 472   1008_DFA_NEU_XX    1008        DFA     NEU        XX
# 473   1008_DFA_SAD_XX    1008        DFA     SAD        XX
# 474   1008_IEO_NEU_XX    1008        IEO     NEU        XX
# 475   1008_IOM_ANG_XX    1008        IOM     ANG        XX
# 476   1008_IOM_DIS_XX    1008        IOM     DIS        XX
# 477   1008_IOM_FEA_XX    1008        IOM     FEA        XX
# 478   1008_IOM_HAP_XX    1008        IOM     HAP        XX
# 479   1008_IOM_NEU_XX    1008        IOM     NEU        XX
# 480   1008_IOM_SAD_XX    1008        IOM     SAD        XX
# 481   1008_ITH_ANG_XX    1008        ITH     ANG        XX
# 482   1008_ITH_DIS_XX    1008        ITH     DIS        XX
# 483   1008_ITH_FEA_XX    1008        ITH     FEA        XX
# 484   1008_ITH_HAP_XX    1008        ITH     HAP        XX
# 485   1008_ITH_NEU_XX    1008        ITH     NEU        XX
# 486   1008_ITH_SAD_XX    1008        ITH     SAD        XX
# 487   1008_ITS_ANG_XX    1008        ITS     ANG        XX
# 488   1008_ITS_DIS_XX    1008        ITS     DIS        XX
# 489   1008_ITS_FEA_XX    1008        ITS     FEA        XX
# 490   1008_ITS_HAP_XX    1008        ITS     HAP        XX
# 491   1008_ITS_NEU_XX    1008        ITS     NEU        XX
# 492   1008_ITS_SAD_XX    1008        ITS     SAD        XX
# 493   1008_IWL_ANG_XX    1008        IWL     ANG        XX
# 494   1008_IWL_DIS_XX    1008        IWL     DIS        XX
# 495   1008_IWL_FEA_XX    1008        IWL     FEA        XX
# 496   1008_IWL_HAP_XX    1008        IWL     HAP        XX
# 497   1008_IWL_NEU_XX    1008        IWL     NEU        XX
# 498   1008_IWL_SAD_XX    1008        IWL     SAD        XX
# 499   1008_IWW_ANG_XX    1008        IWW     ANG        XX
# 500   1008_IWW_DIS_XX    1008        IWW     DIS        XX
# 501   1008_IWW_FEA_XX    1008        IWW     FEA        XX
# 502   1008_IWW_HAP_XX    1008        IWW     HAP        XX
# 503   1008_IWW_NEU_XX    1008        IWW     NEU        XX
# 504   1008_IWW_SAD_XX    1008        IWW     SAD        XX
# 505   1008_MTI_ANG_XX    1008        MTI     ANG        XX
# 506   1008_MTI_DIS_XX    1008        MTI     DIS        XX
# 507   1008_MTI_FEA_XX    1008        MTI     FEA        XX
# 508   1008_MTI_HAP_XX    1008        MTI     HAP        XX
# 509   1008_MTI_NEU_XX    1008        MTI     NEU        XX
# 510   1008_MTI_SAD_XX    1008        MTI     SAD        XX
# 511   1008_TAI_ANG_XX    1008        TAI     ANG        XX
# 512   1008_TAI_DIS_XX    1008        TAI     DIS        XX
# 513   1008_TAI_FEA_XX    1008        TAI     FEA        XX
# 514   1008_TAI_HAP_XX    1008        TAI     HAP        XX
# 515   1008_TAI_NEU_XX    1008        TAI     NEU        XX
# 516   1008_TAI_SAD_XX    1008        TAI     SAD        XX
# 517   1008_TIE_ANG_XX    1008        TIE     ANG        XX
# 518   1008_TIE_DIS_XX    1008        TIE     DIS        XX
# 519   1008_TIE_FEA_XX    1008        TIE     FEA        XX
# 520   1008_TIE_HAP_XX    1008        TIE     HAP        XX
# 521   1008_TIE_NEU_XX    1008        TIE     NEU        XX
# 522   1008_TIE_SAD_XX    1008        TIE     SAD        XX
# 523   1008_TSI_ANG_XX    1008        TSI     ANG        XX
# 524   1008_TSI_DIS_XX    1008        TSI     DIS        XX
# 525   1008_TSI_FEA_XX    1008        TSI     FEA        XX
# 526   1008_TSI_HAP_XX    1008        TSI     HAP        XX
# 527   1008_TSI_NEU_XX    1008        TSI     NEU        XX
# 528   1008_TSI_SAD_XX    1008        TSI     SAD        XX
# 529   1009_DFA_ANG_XX    1009        DFA     ANG        XX
# 530   1009_DFA_DIS_XX    1009        DFA     DIS        XX
# 531   1009_DFA_FEA_XX    1009        DFA     FEA        XX
# 532   1009_DFA_HAP_XX    1009        DFA     HAP        XX
# 533   1009_DFA_NEU_XX    1009        DFA     NEU        XX
# 534   1009_DFA_SAD_XX    1009        DFA     SAD        XX
# 535   1009_IEO_NEU_XX    1009        IEO     NEU        XX
# 536   1009_IOM_ANG_XX    1009        IOM     ANG        XX
# 537   1009_IOM_DIS_XX    1009        IOM     DIS        XX
# 538   1009_IOM_FEA_XX    1009        IOM     FEA        XX
# 539   1009_IOM_HAP_XX    1009        IOM     HAP        XX
# 540   1009_IOM_NEU_XX    1009        IOM     NEU        XX
# 541   1009_IOM_SAD_XX    1009        IOM     SAD        XX
# 542   1009_ITH_ANG_XX    1009        ITH     ANG        XX
# 543   1009_ITH_DIS_XX    1009        ITH     DIS        XX
# 544   1009_ITH_FEA_XX    1009        ITH     FEA        XX
# 545   1009_ITH_HAP_XX    1009        ITH     HAP        XX
# 546   1009_ITH_NEU_XX    1009        ITH     NEU        XX
# 547   1009_ITH_SAD_XX    1009        ITH     SAD        XX
# 548   1009_ITS_ANG_XX    1009        ITS     ANG        XX
# 549   1009_ITS_DIS_XX    1009        ITS     DIS        XX
# 550   1009_ITS_FEA_XX    1009        ITS     FEA        XX
# 551   1009_ITS_HAP_XX    1009        ITS     HAP        XX
# 552   1009_ITS_NEU_XX    1009        ITS     NEU        XX
# 553   1009_ITS_SAD_XX    1009        ITS     SAD        XX
# 554   1009_IWL_ANG_XX    1009        IWL     ANG        XX
# 555   1009_IWL_DIS_XX    1009        IWL     DIS        XX
# 556   1009_IWL_FEA_XX    1009        IWL     FEA        XX
# 557   1009_IWL_HAP_XX    1009        IWL     HAP        XX
# 558   1009_IWL_NEU_XX    1009        IWL     NEU        XX
# 559   1009_IWL_SAD_XX    1009        IWL     SAD        XX
# 560   1009_IWW_ANG_XX    1009        IWW     ANG        XX
# 561   1009_IWW_DIS_XX    1009        IWW     DIS        XX
# 562   1009_IWW_FEA_XX    1009        IWW     FEA        XX
# 563   1009_IWW_HAP_XX    1009        IWW     HAP        XX
# 564   1009_IWW_NEU_XX    1009        IWW     NEU        XX
# 565   1009_IWW_SAD_XX    1009        IWW     SAD        XX
# 566   1009_TAI_ANG_XX    1009        TAI     ANG        XX
# 567   1009_TAI_DIS_XX    1009        TAI     DIS        XX
# 568   1009_TAI_FEA_XX    1009        TAI     FEA        XX
# 569   1009_TAI_HAP_XX    1009        TAI     HAP        XX
# 570   1009_TAI_NEU_XX    1009        TAI     NEU        XX
# 571   1009_TAI_SAD_XX    1009        TAI     SAD        XX
# 572   1009_TIE_ANG_XX    1009        TIE     ANG        XX
# 573   1009_TIE_DIS_XX    1009        TIE     DIS        XX
# 574   1009_TIE_FEA_XX    1009        TIE     FEA        XX
# 575   1009_TIE_HAP_XX    1009        TIE     HAP        XX
# 576   1009_TIE_NEU_XX    1009        TIE     NEU        XX
# 577   1009_TIE_SAD_XX    1009        TIE     SAD        XX
# 578   1009_TSI_ANG_XX    1009        TSI     ANG        XX
# 579   1009_TSI_DIS_XX    1009        TSI     DIS        XX
# 580   1009_TSI_FEA_XX    1009        TSI     FEA        XX
# 581   1009_TSI_HAP_XX    1009        TSI     HAP        XX
# 582   1009_TSI_NEU_XX    1009        TSI     NEU        XX
# 583   1009_TSI_SAD_XX    1009        TSI     SAD        XX
# 584   1009_WSI_ANG_XX    1009        WSI     ANG        XX
# 585   1009_WSI_DIS_XX    1009        WSI     DIS        XX
# 586   1009_WSI_FEA_XX    1009        WSI     FEA        XX
# 587   1009_WSI_HAP_XX    1009        WSI     HAP        XX
# 588   1009_WSI_NEU_XX    1009        WSI     NEU        XX
# 589   1009_WSI_SAD_XX    1009        WSI     SAD        XX
# 590   1010_DFA_ANG_XX    1010        DFA     ANG        XX
# 591   1010_DFA_DIS_XX    1010        DFA     DIS        XX
# 592   1010_DFA_FEA_XX    1010        DFA     FEA        XX
# 593   1010_DFA_HAP_XX    1010        DFA     HAP        XX
# 594   1010_DFA_NEU_XX    1010        DFA     NEU        XX
# 595   1010_DFA_SAD_XX    1010        DFA     SAD        XX
# 596   1010_IEO_NEU_XX    1010        IEO     NEU        XX
# 597   1010_IOM_ANG_XX    1010        IOM     ANG        XX
# 598   1010_IOM_DIS_XX    1010        IOM     DIS        XX
# 599   1010_IOM_FEA_XX    1010        IOM     FEA        XX
# 600   1010_IOM_HAP_XX    1010        IOM     HAP        XX
# 601   1010_IOM_NEU_XX    1010        IOM     NEU        XX
# 602   1010_IOM_SAD_XX    1010        IOM     SAD        XX
# 603   1010_ITH_ANG_XX    1010        ITH     ANG        XX
# 604   1010_ITH_DIS_XX    1010        ITH     DIS        XX
# 605   1010_ITH_FEA_XX    1010        ITH     FEA        XX
# 606   1010_ITH_HAP_XX    1010        ITH     HAP        XX
# 607   1010_ITH_NEU_XX    1010        ITH     NEU        XX
# 608   1010_ITH_SAD_XX    1010        ITH     SAD        XX
# 609   1010_ITS_ANG_XX    1010        ITS     ANG        XX
# 610   1010_ITS_DIS_XX    1010        ITS     DIS        XX
# 611   1010_ITS_FEA_XX    1010        ITS     FEA        XX
# 612   1010_ITS_HAP_XX    1010        ITS     HAP        XX
# 613   1010_ITS_NEU_XX    1010        ITS     NEU        XX
# 614   1010_ITS_SAD_XX    1010        ITS     SAD        XX
# 615   1010_IWL_ANG_XX    1010        IWL     ANG        XX
# 616   1010_IWL_DIS_XX    1010        IWL     DIS        XX
# 617   1010_IWL_FEA_XX    1010        IWL     FEA        XX
# 618   1010_IWL_HAP_XX    1010        IWL     HAP        XX
# 619   1010_IWL_NEU_XX    1010        IWL     NEU        XX
# 620   1010_IWL_SAD_XX    1010        IWL     SAD        XX
# 621   1010_IWW_ANG_XX    1010        IWW     ANG        XX
# 622   1010_IWW_DIS_XX    1010        IWW     DIS        XX
# 623   1010_IWW_FEA_XX    1010        IWW     FEA        XX
# 624   1010_IWW_HAP_XX    1010        IWW     HAP        XX
# 625   1010_IWW_NEU_XX    1010        IWW     NEU        XX
# 626   1010_IWW_SAD_XX    1010        IWW     SAD        XX
# 627   1010_MTI_ANG_XX    1010        MTI     ANG        XX
# 628   1010_MTI_DIS_XX    1010        MTI     DIS        XX
# 629   1010_MTI_FEA_XX    1010        MTI     FEA        XX
# 630   1010_MTI_HAP_XX    1010        MTI     HAP        XX
# 631   1010_MTI_NEU_XX    1010        MTI     NEU        XX
# 632   1010_MTI_SAD_XX    1010        MTI     SAD        XX
# 633   1010_TAI_ANG_XX    1010        TAI     ANG        XX
# 634   1010_TAI_DIS_XX    1010        TAI     DIS        XX
# 635   1010_TAI_FEA_XX    1010        TAI     FEA        XX
# 636   1010_TAI_HAP_XX    1010        TAI     HAP        XX
# 637   1010_TAI_NEU_XX    1010        TAI     NEU        XX
# 638   1010_TAI_SAD_XX    1010        TAI     SAD        XX
# 639   1010_TIE_ANG_XX    1010        TIE     ANG        XX
# 640   1010_TIE_DIS_XX    1010        TIE     DIS        XX
# 641   1010_TIE_FEA_XX    1010        TIE     FEA        XX
# 642   1010_TIE_HAP_XX    1010        TIE     HAP        XX
# 643   1010_TIE_NEU_XX    1010        TIE     NEU        XX
# 644   1010_TIE_SAD_XX    1010        TIE     SAD        XX
# 645   1010_TSI_ANG_XX    1010        TSI     ANG        XX
# 646   1010_TSI_DIS_XX    1010        TSI     DIS        XX
# 647   1010_TSI_FEA_XX    1010        TSI     FEA        XX
# 648   1010_TSI_HAP_XX    1010        TSI     HAP        XX
# 649   1010_TSI_NEU_XX    1010        TSI     NEU        XX
# 650   1010_TSI_SAD_XX    1010        TSI     SAD        XX
# 651   1010_WSI_ANG_XX    1010        WSI     ANG        XX
# 652   1010_WSI_DIS_XX    1010        WSI     DIS        XX
# 653   1010_WSI_FEA_XX    1010        WSI     FEA        XX
# 654   1010_WSI_HAP_XX    1010        WSI     HAP        XX
# 655   1010_WSI_NEU_XX    1010        WSI     NEU        XX
# 656   1010_WSI_SAD_XX    1010        WSI     SAD        XX
# 657   1011_DFA_ANG_XX    1011        DFA     ANG        XX
# 658   1011_DFA_DIS_XX    1011        DFA     DIS        XX
# 659   1011_DFA_FEA_XX    1011        DFA     FEA        XX
# 660   1011_DFA_HAP_XX    1011        DFA     HAP        XX
# 661   1011_DFA_NEU_XX    1011        DFA     NEU        XX
# 662   1011_DFA_SAD_XX    1011        DFA     SAD        XX
# 663   1011_IEO_NEU_XX    1011        IEO     NEU        XX
# 664   1011_IOM_ANG_XX    1011        IOM     ANG        XX
# 665   1011_IOM_DIS_XX    1011        IOM     DIS        XX
# 666   1011_IOM_FEA_XX    1011        IOM     FEA        XX
# 667   1011_IOM_HAP_XX    1011        IOM     HAP        XX
# 668   1011_IOM_NEU_XX    1011        IOM     NEU        XX
# 669   1011_IOM_SAD_XX    1011        IOM     SAD        XX
# 670   1011_ITH_ANG_XX    1011        ITH     ANG        XX
# 671   1011_ITH_DIS_XX    1011        ITH     DIS        XX
# 672   1011_ITH_FEA_XX    1011        ITH     FEA        XX
# 673   1011_ITH_HAP_XX    1011        ITH     HAP        XX
# 674   1011_ITH_NEU_XX    1011        ITH     NEU        XX
# 675   1011_ITH_SAD_XX    1011        ITH     SAD        XX
# 676   1011_ITS_ANG_XX    1011        ITS     ANG        XX
# 677   1011_ITS_DIS_XX    1011        ITS     DIS        XX
# 678   1011_ITS_FEA_XX    1011        ITS     FEA        XX
# 679   1011_ITS_HAP_XX    1011        ITS     HAP        XX
# 680   1011_ITS_NEU_XX    1011        ITS     NEU        XX
# 681   1011_ITS_SAD_XX    1011        ITS     SAD        XX
# 682   1011_IWL_ANG_XX    1011        IWL     ANG        XX
# 683   1011_IWL_DIS_XX    1011        IWL     DIS        XX
# 684   1011_IWL_FEA_XX    1011        IWL     FEA        XX
# 685   1011_IWL_HAP_XX    1011        IWL     HAP        XX
# 686   1011_IWL_NEU_XX    1011        IWL     NEU        XX
# 687   1011_IWL_SAD_XX    1011        IWL     SAD        XX
# 688   1011_IWW_ANG_XX    1011        IWW     ANG        XX
# 689   1011_IWW_DIS_XX    1011        IWW     DIS        XX
# 690   1011_IWW_FEA_XX    1011        IWW     FEA        XX
# 691   1011_IWW_HAP_XX    1011        IWW     HAP        XX
# 692   1011_IWW_NEU_XX    1011        IWW     NEU        XX
# 693   1011_IWW_SAD_XX    1011        IWW     SAD        XX
# 694   1011_MTI_ANG_XX    1011        MTI     ANG        XX
# 695   1011_MTI_DIS_XX    1011        MTI     DIS        XX
# 696   1011_MTI_FEA_XX    1011        MTI     FEA        XX
# 697   1011_MTI_HAP_XX    1011        MTI     HAP        XX
# 698   1011_MTI_NEU_XX    1011        MTI     NEU        XX
# 699   1011_MTI_SAD_XX    1011        MTI     SAD        XX
# 700   1011_TAI_ANG_XX    1011        TAI     ANG        XX
# 701   1011_TAI_DIS_XX    1011        TAI     DIS        XX
# 702   1011_TAI_FEA_XX    1011        TAI     FEA        XX
# 703   1011_TAI_HAP_XX    1011        TAI     HAP        XX
# 704   1011_TAI_NEU_XX    1011        TAI     NEU        XX
# 705   1011_TAI_SAD_XX    1011        TAI     SAD        XX
# 706   1011_TIE_ANG_XX    1011        TIE     ANG        XX
# 707   1011_TIE_DIS_XX    1011        TIE     DIS        XX
# 708   1011_TIE_FEA_XX    1011        TIE     FEA        XX
# 709   1011_TIE_HAP_XX    1011        TIE     HAP        XX
# 710   1011_TIE_NEU_XX    1011        TIE     NEU        XX
# 711   1011_TIE_SAD_XX    1011        TIE     SAD        XX
# 712   1011_TSI_ANG_XX    1011        TSI     ANG        XX
# 713   1011_TSI_DIS_XX    1011        TSI     DIS        XX
# 714   1011_TSI_FEA_XX    1011        TSI     FEA        XX
# 715   1011_TSI_HAP_XX    1011        TSI     HAP        XX
# 716   1011_TSI_NEU_XX    1011        TSI     NEU        XX
# 717   1011_TSI_SAD_XX    1011        TSI     SAD        XX
# 718   1011_WSI_ANG_XX    1011        WSI     ANG        XX
# 719   1011_WSI_DIS_XX    1011        WSI     DIS        XX
# 720   1011_WSI_FEA_XX    1011        WSI     FEA        XX
# 721   1011_WSI_HAP_XX    1011        WSI     HAP        XX
# 722   1011_WSI_NEU_XX    1011        WSI     NEU        XX
# 723   1011_WSI_SAD_XX    1011        WSI     SAD        XX
# 724   1012_DFA_ANG_XX    1012        DFA     ANG        XX
# 725   1012_DFA_DIS_XX    1012        DFA     DIS        XX
# 726   1012_DFA_FEA_XX    1012        DFA     FEA        XX
# 727   1012_DFA_HAP_XX    1012        DFA     HAP        XX
# 728   1012_DFA_NEU_XX    1012        DFA     NEU        XX
# 729   1012_DFA_SAD_XX    1012        DFA     SAD        XX
# 730   1012_IEO_NEU_XX    1012        IEO     NEU        XX
# 731   1012_IOM_ANG_XX    1012        IOM     ANG        XX
# 732   1012_IOM_DIS_XX    1012        IOM     DIS        XX
# 733   1012_IOM_FEA_XX    1012        IOM     FEA        XX
# 734   1012_IOM_HAP_XX    1012        IOM     HAP        XX
# 735   1012_IOM_NEU_XX    1012        IOM     NEU        XX
# 736   1012_IOM_SAD_XX    1012        IOM     SAD        XX
# 737   1012_ITH_ANG_XX    1012        ITH     ANG        XX
# 738   1012_ITH_DIS_XX    1012        ITH     DIS        XX
# 739   1012_ITH_FEA_XX    1012        ITH     FEA        XX
# 740   1012_ITH_HAP_XX    1012        ITH     HAP        XX
# 741   1012_ITH_NEU_XX    1012        ITH     NEU        XX
# 742   1012_ITH_SAD_XX    1012        ITH     SAD        XX
# 743   1012_ITS_ANG_XX    1012        ITS     ANG        XX
# 744   1012_ITS_DIS_XX    1012        ITS     DIS        XX
# 745   1012_ITS_FEA_XX    1012        ITS     FEA        XX
# 746   1012_ITS_HAP_XX    1012        ITS     HAP        XX
# 747   1012_ITS_NEU_XX    1012        ITS     NEU        XX
# 748   1012_ITS_SAD_XX    1012        ITS     SAD        XX
# 749   1012_IWL_ANG_XX    1012        IWL     ANG        XX
# 750   1012_IWL_DIS_XX    1012        IWL     DIS        XX
# 751   1012_IWL_FEA_XX    1012        IWL     FEA        XX
# 752   1012_IWL_HAP_XX    1012        IWL     HAP        XX
# 753   1012_IWL_NEU_XX    1012        IWL     NEU        XX
# 754   1012_IWL_SAD_XX    1012        IWL     SAD        XX
# 755   1012_IWW_ANG_XX    1012        IWW     ANG        XX
# 756   1012_IWW_DIS_XX    1012        IWW     DIS        XX
# 757   1012_IWW_FEA_XX    1012        IWW     FEA        XX
# 758   1012_IWW_HAP_XX    1012        IWW     HAP        XX
# 759   1012_IWW_NEU_XX    1012        IWW     NEU        XX
# 760   1012_IWW_SAD_XX    1012        IWW     SAD        XX
# 761   1012_MTI_ANG_XX    1012        MTI     ANG        XX
# 762   1012_MTI_DIS_XX    1012        MTI     DIS        XX
# 763   1012_MTI_FEA_XX    1012        MTI     FEA        XX
# 764   1012_MTI_HAP_XX    1012        MTI     HAP        XX
# 765   1012_MTI_NEU_XX    1012        MTI     NEU        XX
# 766   1012_MTI_SAD_XX    1012        MTI     SAD        XX
# 767   1012_TAI_ANG_XX    1012        TAI     ANG        XX
# 768   1012_TAI_DIS_XX    1012        TAI     DIS        XX
# 769   1012_TAI_FEA_XX    1012        TAI     FEA        XX
# 770   1012_TAI_HAP_XX    1012        TAI     HAP        XX
# 771   1012_TAI_NEU_XX    1012        TAI     NEU        XX
# 772   1012_TAI_SAD_XX    1012        TAI     SAD        XX
# 773   1012_TIE_ANG_XX    1012        TIE     ANG        XX
# 774   1012_TIE_DIS_XX    1012        TIE     DIS        XX
# 775   1012_TIE_FEA_XX    1012        TIE     FEA        XX
# 776   1012_TIE_HAP_XX    1012        TIE     HAP        XX
# 777   1012_TIE_NEU_XX    1012        TIE     NEU        XX
# 778   1012_TIE_SAD_XX    1012        TIE     SAD        XX
# 779   1012_TSI_ANG_XX    1012        TSI     ANG        XX
# 780   1012_TSI_DIS_XX    1012        TSI     DIS        XX
# 781   1012_TSI_FEA_XX    1012        TSI     FEA        XX
# 782   1012_TSI_HAP_XX    1012        TSI     HAP        XX
# 783   1012_TSI_NEU_XX    1012        TSI     NEU        XX
# 784   1012_TSI_SAD_XX    1012        TSI     SAD        XX
# 785   1012_WSI_ANG_XX    1012        WSI     ANG        XX
# 786   1012_WSI_DIS_XX    1012        WSI     DIS        XX
# 787   1012_WSI_FEA_XX    1012        WSI     FEA        XX
# 788   1012_WSI_HAP_XX    1012        WSI     HAP        XX
# 789   1012_WSI_NEU_XX    1012        WSI     NEU        XX
# 790   1012_WSI_SAD_XX    1012        WSI     SAD        XX
# 791   1013_DFA_ANG_XX    1013        DFA     ANG        XX
# 792   1013_DFA_DIS_XX    1013        DFA     DIS        XX
# 793   1013_DFA_FEA_XX    1013        DFA     FEA        XX
# 794   1013_DFA_HAP_XX    1013        DFA     HAP        XX
# 795   1013_DFA_NEU_XX    1013        DFA     NEU        XX
# 796   1013_DFA_SAD_XX    1013        DFA     SAD        XX
# 797   1013_IEO_NEU_XX    1013        IEO     NEU        XX
# 798   1013_IOM_ANG_XX    1013        IOM     ANG        XX
# 799   1013_IOM_DIS_XX    1013        IOM     DIS        XX
# 800   1013_IOM_FEA_XX    1013        IOM     FEA        XX
# 801   1013_IOM_HAP_XX    1013        IOM     HAP        XX
# 802   1013_IOM_NEU_XX    1013        IOM     NEU        XX
# 803   1013_IOM_SAD_XX    1013        IOM     SAD        XX
# 804   1013_ITH_ANG_XX    1013        ITH     ANG        XX
# 805   1013_ITH_DIS_XX    1013        ITH     DIS        XX
# 806   1013_ITH_FEA_XX    1013        ITH     FEA        XX
# 807   1013_ITH_HAP_XX    1013        ITH     HAP        XX
# 808   1013_ITH_NEU_XX    1013        ITH     NEU        XX
# 809   1013_ITH_SAD_XX    1013        ITH     SAD        XX
# 810   1013_ITS_ANG_XX    1013        ITS     ANG        XX
# 811   1013_ITS_DIS_XX    1013        ITS     DIS        XX
# ...
# 5806  1087_WSI_HAP_XX    1087        WSI     HAP        XX
# 5807  1087_WSI_NEU_XX    1087        WSI     NEU        XX
# 5808  1087_WSI_SAD_XX    1087        WSI     SAD        XX
# 5809  1088_DFA_ANG_XX    1088        DFA     ANG        XX
# 5810  1088_DFA_DIS_XX    1088        DFA     DIS        XX
# 5811  1088_DFA_FEA_XX    1088        DFA     FEA        XX
# 5812  1088_DFA_HAP_XX    1088        DFA     HAP        XX
# 5813  1088_DFA_NEU_XX    1088        DFA     NEU        XX
# 5814  1088_DFA_SAD_XX    1088        DFA     SAD        XX
# 5815  1088_IEO_NEU_XX    1088        IEO     NEU        XX
# 5816  1088_IOM_ANG_XX    1088        IOM     ANG        XX
# 5817  1088_IOM_DIS_XX    1088        IOM     DIS        XX
# 5818  1088_IOM_FEA_XX    1088        IOM     FEA        XX
# 5819  1088_IOM_HAP_XX    1088        IOM     HAP        XX
# 5820  1088_IOM_NEU_XX    1088        IOM     NEU        XX
# 5821  1088_IOM_SAD_XX    1088        IOM     SAD        XX
# 5822  1088_ITH_ANG_XX    1088        ITH     ANG        XX
# 5823  1088_ITH_DIS_XX    1088        ITH     DIS        XX
# 5824  1088_ITH_FEA_XX    1088        ITH     FEA        XX
# 5825  1088_ITH_HAP_XX    1088        ITH     HAP        XX
# 5826  1088_ITH_NEU_XX    1088        ITH     NEU        XX
# 5827  1088_ITH_SAD_XX    1088        ITH     SAD        XX
# 5828  1088_ITS_ANG_XX    1088        ITS     ANG        XX
# 5829  1088_ITS_DIS_XX    1088        ITS     DIS        XX
# 5830  1088_ITS_FEA_XX    1088        ITS     FEA        XX
# 5831  1088_ITS_HAP_XX    1088        ITS     HAP        XX
# 5832  1088_ITS_NEU_XX    1088        ITS     NEU        XX
# 5833  1088_ITS_SAD_XX    1088        ITS     SAD        XX
# 5834  1088_IWL_ANG_XX    1088        IWL     ANG        XX
# 5835  1088_IWL_DIS_XX    1088        IWL     DIS        XX
# 5836  1088_IWL_FEA_XX    1088        IWL     FEA        XX
# 5837  1088_IWL_HAP_XX    1088        IWL     HAP        XX
# 5838  1088_IWL_NEU_XX    1088        IWL     NEU        XX
# 5839  1088_IWL_SAD_XX    1088        IWL     SAD        XX
# 5840  1088_IWW_ANG_XX    1088        IWW     ANG        XX
# 5841  1088_IWW_DIS_XX    1088        IWW     DIS        XX
# 5842  1088_IWW_FEA_XX    1088        IWW     FEA        XX
# 5843  1088_IWW_HAP_XX    1088        IWW     HAP        XX
# 5844  1088_IWW_NEU_XX    1088        IWW     NEU        XX
# 5845  1088_IWW_SAD_XX    1088        IWW     SAD        XX
# 5846  1088_MTI_ANG_XX    1088        MTI     ANG        XX
# 5847  1088_MTI_DIS_XX    1088        MTI     DIS        XX
# 5848  1088_MTI_FEA_XX    1088        MTI     FEA        XX
# 5849  1088_MTI_HAP_XX    1088        MTI     HAP        XX
# 5850  1088_MTI_NEU_XX    1088        MTI     NEU        XX
# 5851  1088_MTI_SAD_XX    1088        MTI     SAD        XX
# 5852  1088_TAI_ANG_XX    1088        TAI     ANG        XX
# 5853  1088_TAI_DIS_XX    1088        TAI     DIS        XX
# 5854  1088_TAI_FEA_XX    1088        TAI     FEA        XX
# 5855  1088_TAI_HAP_XX    1088        TAI     HAP        XX
# 5856  1088_TAI_NEU_XX    1088        TAI     NEU        XX
# 5857  1088_TAI_SAD_XX    1088        TAI     SAD        XX
# 5858  1088_TIE_ANG_XX    1088        TIE     ANG        XX
# 5859  1088_TIE_DIS_XX    1088        TIE     DIS        XX
# 5860  1088_TIE_FEA_XX    1088        TIE     FEA        XX
# 5861  1088_TIE_HAP_XX    1088        TIE     HAP        XX
# 5862  1088_TIE_NEU_XX    1088        TIE     NEU        XX
# 5863  1088_TIE_SAD_XX    1088        TIE     SAD        XX
# 5864  1088_TSI_ANG_XX    1088        TSI     ANG        XX
# 5865  1088_TSI_DIS_XX    1088        TSI     DIS        XX
# 5866  1088_TSI_FEA_XX    1088        TSI     FEA        XX
# 5867  1088_TSI_HAP_XX    1088        TSI     HAP        XX
# 5868  1088_TSI_NEU_XX    1088        TSI     NEU        XX
# 5869  1088_TSI_SAD_XX    1088        TSI     SAD        XX
# 5870  1088_WSI_ANG_XX    1088        WSI     ANG        XX
# 5871  1088_WSI_DIS_XX    1088        WSI     DIS        XX
# 5872  1088_WSI_FEA_XX    1088        WSI     FEA        XX
# 5873  1088_WSI_HAP_XX    1088        WSI     HAP        XX
# 5874  1088_WSI_NEU_XX    1088        WSI     NEU        XX
# 5875  1088_WSI_SAD_XX    1088        WSI     SAD        XX
# 5876  1089_DFA_ANG_XX    1089        DFA     ANG        XX
# 5877  1089_DFA_DIS_XX    1089        DFA     DIS        XX
# 5878  1089_DFA_FEA_XX    1089        DFA     FEA        XX
# 5879  1089_DFA_HAP_XX    1089        DFA     HAP        XX
# 5880  1089_DFA_NEU_XX    1089        DFA     NEU        XX
# 5881  1089_DFA_SAD_XX    1089        DFA     SAD        XX
# 5882  1089_IEO_NEU_XX    1089        IEO     NEU        XX
# 5883  1089_IOM_ANG_XX    1089        IOM     ANG        XX
# 5884  1089_IOM_DIS_XX    1089        IOM     DIS        XX
# 5885  1089_IOM_FEA_XX    1089        IOM     FEA        XX
# 5886  1089_IOM_HAP_XX    1089        IOM     HAP        XX
# 5887  1089_IOM_NEU_XX    1089        IOM     NEU        XX
# 5888  1089_IOM_SAD_XX    1089        IOM     SAD        XX
# 5889  1089_ITH_ANG_XX    1089        ITH     ANG        XX
# 5890  1089_ITH_DIS_XX    1089        ITH     DIS        XX
# 5891  1089_ITH_FEA_XX    1089        ITH     FEA        XX
# 5892  1089_ITH_HAP_XX    1089        ITH     HAP        XX
# 5893  1089_ITH_NEU_XX    1089        ITH     NEU        XX
# 5894  1089_ITH_SAD_XX    1089        ITH     SAD        XX
# 5895  1089_ITS_ANG_XX    1089        ITS     ANG        XX
# 5896  1089_ITS_DIS_XX    1089        ITS     DIS        XX
# 5897  1089_ITS_FEA_XX    1089        ITS     FEA        XX
# 5898  1089_ITS_HAP_XX    1089        ITS     HAP        XX
# 5899  1089_ITS_NEU_XX    1089        ITS     NEU        XX
# 5900  1089_ITS_SAD_XX    1089        ITS     SAD        XX
# 5901  1089_IWL_ANG_XX    1089        IWL     ANG        XX
# 5902  1089_IWL_DIS_XX    1089        IWL     DIS        XX
# 5903  1089_IWL_FEA_XX    1089        IWL     FEA        XX
# 5904  1089_IWL_HAP_XX    1089        IWL     HAP        XX
# 5905  1089_IWL_NEU_XX    1089        IWL     NEU        XX
# 5906  1089_IWL_SAD_XX    1089        IWL     SAD        XX
# 5907  1089_IWW_ANG_XX    1089        IWW     ANG        XX
# 5908  1089_IWW_DIS_XX    1089        IWW     DIS        XX
# 5909  1089_IWW_FEA_XX    1089        IWW     FEA        XX
# 5910  1089_IWW_HAP_XX    1089        IWW     HAP        XX
# 5911  1089_IWW_NEU_XX    1089        IWW     NEU        XX
# 5912  1089_IWW_SAD_XX    1089        IWW     SAD        XX
# 5913  1089_MTI_ANG_XX    1089        MTI     ANG        XX
# 5914  1089_MTI_DIS_XX    1089        MTI     DIS        XX
# 5915  1089_MTI_FEA_XX    1089        MTI     FEA        XX
# 5916  1089_MTI_HAP_XX    1089        MTI     HAP        XX
# 5917  1089_MTI_NEU_XX    1089        MTI     NEU        XX
# 5918  1089_MTI_SAD_XX    1089        MTI     SAD        XX
# 5919  1089_TAI_ANG_XX    1089        TAI     ANG        XX
# 5920  1089_TAI_DIS_XX    1089        TAI     DIS        XX
# 5921  1089_TAI_FEA_XX    1089        TAI     FEA        XX
# 5922  1089_TAI_HAP_XX    1089        TAI     HAP        XX
# 5923  1089_TAI_NEU_XX    1089        TAI     NEU        XX
# 5924  1089_TAI_SAD_XX    1089        TAI     SAD        XX
# 5925  1089_TIE_ANG_XX    1089        TIE     ANG        XX
# 5926  1089_TIE_DIS_XX    1089        TIE     DIS        XX
# 5927  1089_TIE_FEA_XX    1089        TIE     FEA        XX
# 5928  1089_TIE_HAP_XX    1089        TIE     HAP        XX
# 5929  1089_TIE_NEU_XX    1089        TIE     NEU        XX
# 5930  1089_TIE_SAD_XX    1089        TIE     SAD        XX
# 5931  1089_TSI_ANG_XX    1089        TSI     ANG        XX
# 5932  1089_TSI_DIS_XX    1089        TSI     DIS        XX
# 5933  1089_TSI_FEA_XX    1089        TSI     FEA        XX
# 5934  1089_TSI_HAP_XX    1089        TSI     HAP        XX
# 5935  1089_TSI_NEU_XX    1089        TSI     NEU        XX
# 5936  1089_TSI_SAD_XX    1089        TSI     SAD        XX
# 5937  1089_WSI_ANG_XX    1089        WSI     ANG        XX
# 5938  1089_WSI_DIS_XX    1089        WSI     DIS        XX
# 5939  1089_WSI_FEA_XX    1089        WSI     FEA        XX
# 5940  1089_WSI_HAP_XX    1089        WSI     HAP        XX
# 5941  1089_WSI_NEU_XX    1089        WSI     NEU        XX
# 5942  1089_WSI_SAD_XX    1089        WSI     SAD        XX
# 5943  1090_DFA_ANG_XX    1090        DFA     ANG        XX
# 5944  1090_DFA_DIS_XX    1090        DFA     DIS        XX
# 5945  1090_DFA_FEA_XX    1090        DFA     FEA        XX
# 5946  1090_DFA_HAP_XX    1090        DFA     HAP        XX
# 5947  1090_DFA_NEU_XX    1090        DFA     NEU        XX
# 5948  1090_DFA_SAD_XX    1090        DFA     SAD        XX
# 5949  1090_IEO_NEU_XX    1090        IEO     NEU        XX
# 5950  1090_IOM_ANG_XX    1090        IOM     ANG        XX
# 5951  1090_IOM_DIS_XX    1090        IOM     DIS        XX
# 5952  1090_IOM_FEA_XX    1090        IOM     FEA        XX
# 5953  1090_IOM_HAP_XX    1090        IOM     HAP        XX
# 5954  1090_IOM_NEU_XX    1090        IOM     NEU        XX
# 5955  1090_IOM_SAD_XX    1090        IOM     SAD        XX
# 5956  1090_ITH_ANG_XX    1090        ITH     ANG        XX
# 5957  1090_ITH_DIS_XX    1090        ITH     DIS        XX
# 5958  1090_ITH_FEA_XX    1090        ITH     FEA        XX
# 5959  1090_ITH_HAP_XX    1090        ITH     HAP        XX
# 5960  1090_ITH_NEU_XX    1090        ITH     NEU        XX
# 5961  1090_ITH_SAD_XX    1090        ITH     SAD        XX
# 5962  1090_ITS_ANG_XX    1090        ITS     ANG        XX
# 5963  1090_ITS_DIS_XX    1090        ITS     DIS        XX
# 5964  1090_ITS_FEA_XX    1090        ITS     FEA        XX
# 5965  1090_ITS_HAP_XX    1090        ITS     HAP        XX
# 5966  1090_ITS_NEU_XX    1090        ITS     NEU        XX
# 5967  1090_ITS_SAD_XX    1090        ITS     SAD        XX
# 5968  1090_IWL_ANG_XX    1090        IWL     ANG        XX
# 5969  1090_IWL_DIS_XX    1090        IWL     DIS        XX
# 5970  1090_IWL_FEA_XX    1090        IWL     FEA        XX
# 5971  1090_IWL_HAP_XX    1090        IWL     HAP        XX
# 5972  1090_IWL_NEU_XX    1090        IWL     NEU        XX
# 5973  1090_IWL_SAD_XX    1090        IWL     SAD        XX
# 5974  1090_IWW_ANG_XX    1090        IWW     ANG        XX
# 5975  1090_IWW_DIS_XX    1090        IWW     DIS        XX
# 5976  1090_IWW_FEA_XX    1090        IWW     FEA        XX
# 5977  1090_IWW_HAP_XX    1090        IWW     HAP        XX
# 5978  1090_IWW_NEU_XX    1090        IWW     NEU        XX
# 5979  1090_IWW_SAD_XX    1090        IWW     SAD        XX
# 5980  1090_MTI_ANG_XX    1090        MTI     ANG        XX
# 5981  1090_MTI_DIS_XX    1090        MTI     DIS        XX
# 5982  1090_MTI_FEA_XX    1090        MTI     FEA        XX
# 5983  1090_MTI_HAP_XX    1090        MTI     HAP        XX
# 5984  1090_MTI_NEU_XX    1090        MTI     NEU        XX
# 5985  1090_MTI_SAD_XX    1090        MTI     SAD        XX
# 5986  1090_TAI_ANG_XX    1090        TAI     ANG        XX
# 5987  1090_TAI_DIS_XX    1090        TAI     DIS        XX
# 5988  1090_TAI_FEA_XX    1090        TAI     FEA        XX
# 5989  1090_TAI_HAP_XX    1090        TAI     HAP        XX
# 5990  1090_TAI_NEU_XX    1090        TAI     NEU        XX
# 5991  1090_TAI_SAD_XX    1090        TAI     SAD        XX
# 5992  1090_TIE_ANG_XX    1090        TIE     ANG        XX
# 5993  1090_TIE_DIS_XX    1090        TIE     DIS        XX
# 5994  1090_TIE_FEA_XX    1090        TIE     FEA        XX
# 5995  1090_TIE_HAP_XX    1090        TIE     HAP        XX
# 5996  1090_TIE_NEU_XX    1090        TIE     NEU        XX
# 5997  1090_TIE_SAD_XX    1090        TIE     SAD        XX
# 5998  1090_TSI_ANG_XX    1090        TSI     ANG        XX
# 5999  1090_TSI_DIS_XX    1090        TSI     DIS        XX
# 6000  1090_TSI_FEA_XX    1090        TSI     FEA        XX
# 6001  1090_TSI_HAP_XX    1090        TSI     HAP        XX
# 6002  1090_TSI_NEU_XX    1090        TSI     NEU        XX
# 6003  1090_TSI_SAD_XX    1090        TSI     SAD        XX
# 6004  1090_WSI_ANG_XX    1090        WSI     ANG        XX
# 6005  1090_WSI_DIS_XX    1090        WSI     DIS        XX
# 6006  1090_WSI_FEA_XX    1090        WSI     FEA        XX
# 6007  1090_WSI_HAP_XX    1090        WSI     HAP        XX
# 6008  1090_WSI_NEU_XX    1090        WSI     NEU        XX
# 6009  1090_WSI_SAD_XX    1090        WSI     SAD        XX
# 6010  1091_DFA_ANG_XX    1091        DFA     ANG        XX
# 6011  1091_DFA_DIS_XX    1091        DFA     DIS        XX
# 6012  1091_DFA_FEA_XX    1091        DFA     FEA        XX
# 6013  1091_DFA_HAP_XX    1091        DFA     HAP        XX
# 6014  1091_DFA_NEU_XX    1091        DFA     NEU        XX
# 6015  1091_DFA_SAD_XX    1091        DFA     SAD        XX
# 6016  1091_IEO_NEU_XX    1091        IEO     NEU        XX
# 6017  1091_IOM_ANG_XX    1091        IOM     ANG        XX
# 6018  1091_IOM_DIS_XX    1091        IOM     DIS        XX
# 6019  1091_IOM_FEA_XX    1091        IOM     FEA        XX
# 6020  1091_IOM_HAP_XX    1091        IOM     HAP        XX
# 6021  1091_IOM_NEU_XX    1091        IOM     NEU        XX
# 6022  1091_IOM_SAD_XX    1091        IOM     SAD        XX
# 6023  1091_ITH_ANG_XX    1091        ITH     ANG        XX
# 6024  1091_ITH_DIS_XX    1091        ITH     DIS        XX
# 6025  1091_ITH_FEA_XX    1091        ITH     FEA        XX
# 6026  1091_ITH_HAP_XX    1091        ITH     HAP        XX
# 6027  1091_ITH_NEU_XX    1091        ITH     NEU        XX
# 6028  1091_ITH_SAD_XX    1091        ITH     SAD        XX
# 6029  1091_ITS_ANG_XX    1091        ITS     ANG        XX
# 6030  1091_ITS_DIS_XX    1091        ITS     DIS        XX
# 6031  1091_ITS_FEA_XX    1091        ITS     FEA        XX
# 6032  1091_ITS_HAP_XX    1091        ITS     HAP        XX
# 6033  1091_ITS_NEU_XX    1091        ITS     NEU        XX
# 6034  1091_ITS_SAD_XX    1091        ITS     SAD        XX
# 6035  1091_IWL_ANG_XX    1091        IWL     ANG        XX
# 6036  1091_IWL_DIS_XX    1091        IWL     DIS        XX
# 6037  1091_IWL_FEA_XX    1091        IWL     FEA        XX
# 6038  1091_IWL_HAP_XX    1091        IWL     HAP        XX
# 6039  1091_IWL_NEU_XX    1091        IWL     NEU        XX
# 6040  1091_IWL_SAD_XX    1091        IWL     SAD        XX
# 6041  1091_IWW_ANG_XX    1091        IWW     ANG        XX
# 6042  1091_IWW_DIS_XX    1091        IWW     DIS        XX
# 6043  1091_IWW_FEA_XX    1091        IWW     FEA        XX
# 6044  1091_IWW_HAP_XX    1091        IWW     HAP        XX
# 6045  1091_IWW_NEU_XX    1091        IWW     NEU        XX
# 6046  1091_IWW_SAD_XX    1091        IWW     SAD        XX
# 6047  1091_MTI_ANG_XX    1091        MTI     ANG        XX
# 6048  1091_MTI_DIS_XX    1091        MTI     DIS        XX
# 6049  1091_MTI_FEA_XX    1091        MTI     FEA        XX
# 6050  1091_MTI_HAP_XX    1091        MTI     HAP        XX
# 6051  1091_MTI_NEU_XX    1091        MTI     NEU        XX
# 6052  1091_MTI_SAD_XX    1091        MTI     SAD        XX
# 6053  1091_TAI_ANG_XX    1091        TAI     ANG        XX
# 6054  1091_TAI_DIS_XX    1091        TAI     DIS        XX
# 6055  1091_TAI_FEA_XX    1091        TAI     FEA        XX
# 6056  1091_TAI_HAP_XX    1091        TAI     HAP        XX
# 6057  1091_TAI_NEU_XX    1091        TAI     NEU        XX
# 6058  1091_TAI_SAD_XX    1091        TAI     SAD        XX
# 6059  1091_TIE_ANG_XX    1091        TIE     ANG        XX
# 6060  1091_TIE_DIS_XX    1091        TIE     DIS        XX
# 6061  1091_TIE_FEA_XX    1091        TIE     FEA        XX
# 6062  1091_TIE_HAP_XX    1091        TIE     HAP        XX
# 6063  1091_TIE_NEU_XX    1091        TIE     NEU        XX
# 6064  1091_TIE_SAD_XX    1091        TIE     SAD        XX
# 6065  1091_TSI_ANG_XX    1091        TSI     ANG        XX
# 6066  1091_TSI_DIS_XX    1091        TSI     DIS        XX
# 6067  1091_TSI_FEA_XX    1091        TSI     FEA        XX
# 6068  1091_TSI_HAP_XX    1091        TSI     HAP        XX
# 6069  1091_TSI_NEU_XX    1091        TSI     NEU        XX
# 6070  1091_TSI_SAD_XX    1091        TSI     SAD        XX
# 6071  1091_WSI_ANG_XX    1091        WSI     ANG        XX
# 6072  1091_WSI_DIS_XX    1091        WSI     DIS        XX
# 6073  1091_WSI_FEA_XX    1091        WSI     FEA        XX
# 6074  1091_WSI_HAP_XX    1091        WSI     HAP        XX
# 6075  1091_WSI_NEU_XX    1091        WSI     NEU        XX
# 6076  1091_WSI_SAD_XX    1091        WSI     SAD        XX

# %% [markdown]
# ### Second part: With intensities
# For reference, I also process the files with intensities.

# %%
files = os.listdir('../../AudioWAV_Intensity')

time_start = time.time()
df2 = pd.DataFrame(columns = ['FileID', 'ActorID', 'SentenceID', 'Emotion', 'Intensity'],
                  dtype='category')

for file in files:
    fileID = file.split('.')[0]
    cats = fileID.split('_')
    
    new_row = pd.DataFrame([[fileID] + cats],
                        columns = ['FileID', 'ActorID', 'SentenceID', 'Emotion', 'Intensity'])
    df2 = pd.concat((df2,new_row), axis=0)

# Turn columns into factors (except for FileID)
for col in df.columns:
    if col != 'FileID':
        df2[col] = (df2[col]).astype('category')

time_end = time.time()
time_total = time_end-time_start
print('Number of files: %i' %(len(files)))
if time_total <= 60:
    print('Duration: %f (s)' %time_total)
elif 60 < time_total <= 3600:
    print('Duration: %f (min)' %(time_total/60))
else:
    print('Duration: %f (h)' %(time_total/3600))
# Out:
# Number of files: 1365
# Duration: 1.004620 (s)

# %%
df2.describe()
# Out:
#                  FileID ActorID SentenceID Emotion Intensity
# count              1365    1365       1365    1365      1365
# unique             1365      91          1       5         3
# top     1082_IEO_SAD_HI    1001        IEO     ANG        HI
# freq                  1      15       1365     273       455

# %%
print('Actors:')
print(np.unique(df2.ActorID))
print()
print('Sentence:')
print(np.unique(df2.SentenceID))
print()
print('Emotions:')
print(np.unique(df2.Emotion))
print()
print('Intensities:')
print(np.unique(df2.Intensity))
# Out:
# Actors:
# ['1001' '1002' '1003' '1004' '1005' '1006' '1007' '1008' '1009' '1010'
#  '1011' '1012' '1013' '1014' '1015' '1016' '1017' '1018' '1019' '1020'
#  '1021' '1022' '1023' '1024' '1025' '1026' '1027' '1028' '1029' '1030'
#  '1031' '1032' '1033' '1034' '1035' '1036' '1037' '1038' '1039' '1040'
#  '1041' '1042' '1043' '1044' '1045' '1046' '1047' '1048' '1049' '1050'
#  '1051' '1052' '1053' '1054' '1055' '1056' '1057' '1058' '1059' '1060'
#  '1061' '1062' '1063' '1064' '1065' '1066' '1067' '1068' '1069' '1070'
#  '1071' '1072' '1073' '1074' '1075' '1076' '1077' '1078' '1079' '1080'
#  '1081' '1082' '1083' '1084' '1085' '1086' '1087' '1088' '1089' '1090'
#  '1091']
#
# Sentence:
# ['IEO']
#
# Emotions:
# ['ANG' 'DIS' 'FEA' 'HAP' 'SAD']
#
# Intensities:
# ['HI' 'LO' 'MD']

# %%
pd.set_option('display.max_rows', None)
print('ActorID')
print(df2.ActorID.value_counts().sort_index().sort_values())
print()

print('SentenceID')
print(df2.SentenceID.value_counts().sort_index())
print()

print('Emotion')
print(df2.Emotion.value_counts().sort_index())
print()

print('Intensity')
print(df2.Intensity.value_counts().sort_index())
print()
# Out:
# ActorID
# 1001    15
# 1066    15
# 1065    15
# 1064    15
# 1063    15
# 1062    15
# 1061    15
# 1060    15
# 1059    15
# 1058    15
# 1057    15
# 1056    15
# 1055    15
# 1054    15
# 1053    15
# 1052    15
# 1051    15
# 1050    15
# 1049    15
# 1048    15
# 1067    15
# 1047    15
# 1068    15
# 1070    15
# 1089    15
# 1088    15
# 1087    15
# 1086    15
# 1085    15
# 1084    15
# 1083    15
# 1082    15
# 1081    15
# 1080    15
# 1079    15
# 1078    15
# 1077    15
# 1076    15
# 1075    15
# 1074    15
# 1073    15
# 1072    15
# 1071    15
# 1069    15
# 1090    15
# 1046    15
# 1044    15
# 1020    15
# 1019    15
# 1018    15
# 1017    15
# 1016    15
# 1015    15
# 1014    15
# 1013    15
# 1012    15
# 1011    15
# 1010    15
# 1009    15
# 1008    15
# 1007    15
# 1006    15
# 1005    15
# 1004    15
# 1003    15
# 1002    15
# 1021    15
# 1045    15
# 1022    15
# 1024    15
# 1043    15
# 1042    15
# 1041    15
# 1040    15
# 1039    15
# 1038    15
# 1037    15
# 1036    15
# 1035    15
# 1034    15
# 1033    15
# 1032    15
# 1031    15
# 1030    15
# 1029    15
# 1028    15
# 1027    15
# 1026    15
# 1025    15
# 1023    15
# 1091    15
# Name: ActorID, dtype: int64
#
# SentenceID
# IEO    1365
# Name: SentenceID, dtype: int64
#
# Emotion
# ANG    273
# DIS    273
# FEA    273
# HAP    273
# SAD    273
# Name: Emotion, dtype: int64
#
# Intensity
# HI    455
# LO    455
# MD    455
# Name: Intensity, dtype: int64
